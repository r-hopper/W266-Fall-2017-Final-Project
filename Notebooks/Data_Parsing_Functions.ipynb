# %% [markdown]
# # Data Parsing Functions
# `MMV | 12/4 | w266 Final Project: Crosslingual Word Embeddings`
#
#
# The code in this notebook builds on the helper functions provided in the TensorFlow Word2Vec tutorial to develop a set of data handling functions for use with the data relevant to Duong et al's paper. Ideally I'll develop a scalable solution for tokenizing, prepending language indicators (eg. `en_`) and extracting sentences in two langauges to create traning data that includes sentences from two languages. I also hope to develop a batch iterator modeled after the one in A4 and do some EDA related to the Panlex dictionaries in preparation for using these to modify Word2Vec for 2 langauges. Depending on the available tools I may end up needing to look at using a distributed system (Spark?) for preprocessing the English corpus which is ~ 9GB.

# %% [markdown]
# # Notebook Set-up

# %%
# general imports
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import sys  
import math
import random
import sklearn
import numpy as np
import collections
import pandas as pd
import datetime as dt
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf

# tell matplotlib not to open a new window
# %matplotlib inline

# %%
# filepaths
BASE = '/home/mmillervedam/Data'
FPATH_EN = BASE + '/test/wiki_en_10K.txt' # first 10000 lines from wiki dump
FPATH_ES = BASE + '/test/wiki_es_10K.txt' # first 10000 lines from wiki dump
FULL_EN = BASE + '/en/full.txt'
FULL_ES = BASE + '/es/full.txt'
DPATH = '/home/mmillervedam/ProjectRepo/XlingualEmb/data/dicts/en.es.panlex.all.processed'

# %% [markdown]
# # Dictionary EDA

# %%
# load from file
panlex = pd.read_csv(DPATH, sep='\t', names = ['en', 'es'], dtype=str)

# %%
# initial stats
print ('This dictionary contains {} entries.'.format(len(panlex)))
print ('... including {} unique English words.'.format(len(panlex.en.unique())))
print ('... and {} unique Spanish words.'.format(len(panlex.es.unique())))
# Out:
# This dictionary contains 711978 entries.
# ... including 356410 unique English words.
# ... and 346572 unique Spanish words.

# %%
# multiword mappings
en_dict = panlex.groupby(panlex.en).groups

# %%
en_dict # WHY IS THIS NONSENSE!
# Out:
# {'en_guadeloupe': Int64Index([287658], dtype='int64'),
#  'en_roll_up_one\xe2\x80\x99s_sleeves': Int64Index([544095], dtype='int64'),
#  'en_reach_the_point_of': Int64Index([522322], dtype='int64'),
#  'en_ciudad_perdida': Int64Index([123885], dtype='int64'),
#  'en_heather_graham_pozzessere': Int64Index([298060], dtype='int64'),
#  'en_ambient_air,_open_air,_outdoor_air': Int64Index([25848], dtype='int64'),
#  'en_profundity': Int64Index([504466, 504467, 504468, 504469, 504470, 504471], dtype='int64'),
#  'en_lou_reed': Int64Index([384601], dtype='int64'),
#  'en_dicentrarchus_labrax': Int64Index([179848], dtype='int64'),
#  'en_h\xc3\xbasdr\xc3\xa1pa': Int64Index([313326], dtype='int64'),
#  'en_hortensia_bussi': Int64Index([309352], dtype='int64'),
#  'en_motorize': Int64Index([421839], dtype='int64'),
#  'en_state-of-the-art_search_programme': Int64Index([606287], dtype='int64'),
#  'en_telesur': Int64Index([633513], dtype='int64'),
#  'en_infringement_procedure_(eu)': Int64Index([325976], dtype='int64'),
#  'en_barcelona_plan_of_action_for_the_protection_of_the_mediterranean_environment': Int64Index([59823], dtype='int64'),
#  'en_cuzdrioara': Int64Index([162397], dtype='int64'),
#  'en_sydowia': Int64Index([624867], dtype='int64'),
#  'en_woa': Int64Index([700999], dtype='int64'),
#  'en_mark_feehily': Int64Index([398419], dtype='int64'),
#  'en_great_prominent': Int64Index([283750], dtype='int64'),
#  'en_britney_spears': Int64Index([89228], dtype='int64'),
#  'en_winder': Int64Index([698744, 698745, 698746, 698747], dtype='int64'),
#  'en_i_think_i\xe2\x80\x99m_paranoid': Int64Index([340955], dtype='int64'),
#  'en_gravelly': Int64Index([282667, 282668], dtype='int64'),
#  'en_guillermo_d\xc3\xa1vila': Int64Index([288860], dtype='int64'),
#  'en_villa_ballester': Int64Index([682581], dtype='int64'),
#  'en_get_tigh': Int64Index([271526], dtype='int64'),
#  'en_extended_continental_shelf': Int64Index([227510], dtype='int64'),
#  'en_folding_stock': Int64Index([247692], dtype='int64'),
#  'en_making_fire': Int64Index([392461], dtype='int64'),
#  'en_ghrelin': Int64Index([271969], dtype='int64'),
#  'en_absolute_url': Int64Index([2934], dtype='int64'),
#  'en_levitate': Int64Index([373661, 373662], dtype='int64'),
#  'en_olive_cultivation': Int64Index([449851], dtype='int64'),
#  'en_on_one_hand': Int64Index([451332], dtype='int64'),
#  'en_bottle_neck': Int64Index([83814], dtype='int64'),
#  'en_send_in': Int64Index([568466, 568474, 568475], dtype='int64'),
#  'en_paulo_c\xc3\xa9sar_carpegiani': Int64Index([470420], dtype='int64'),
#  'en_bottle_capping': Int64Index([83752, 83753, 83754], dtype='int64'),
#  'en_stroking': Int64Index([614036, 614037, 614038, 614039], dtype='int64'),
#  'en_cabo_de_gata-n\xc3\xadjar_natural_park': Int64Index([96684], dtype='int64'),
#  'en_estadio_el_helm\xc3\xa1ntico': Int64Index([218128], dtype='int64'),
#  'en_lose_consciousness': Int64Index([383697], dtype='int64'),
#  'en_edgar_de_evia': Int64Index([202213], dtype='int64'),
#  'en_parascorpis_typus': Int64Index([466112], dtype='int64'),
#  'en_academy_award_for_makeup': Int64Index([3794], dtype='int64'),
#  'en_cover_crops': Int64Index([153362, 153363], dtype='int64'),
#  'en_usaf': Int64Index([674979], dtype='int64'),
#  'en_european_blister_beetle': Int64Index([220608, 220609, 220610, 220611, 220612, 220613, 220614], dtype='int64'),
#  'en_air_bladder': Int64Index([17696], dtype='int64'),
#  'en_woolgather': Int64Index([702163], dtype='int64'),
#  'en_squirrelly': Int64Index([603226, 603227], dtype='int64'),
#  'en_ursa_minor': Int64Index([674815], dtype='int64'),
#  'en_search_head': Int64Index([562692], dtype='int64'),
#  'en_rollo_may': Int64Index([544007], dtype='int64'),
#  'en_ad_hoc_tripartite_working_group_on_appropriate_technology': Int64Index([9520], dtype='int64'),
#  'en_autarkical': Int64Index([51987], dtype='int64'),
#  'en_chernobyl_nuclear_power_plant': Int64Index([117167], dtype='int64'),
#  'en_lead_us_not_into_temptation': Int64Index([369030], dtype='int64'),
#  'en_final_review_and_appraisal_of_the_implementation_of_the_united_nations_programme_of_action_for_african_economic_recovery_and_development_1986-1990': Int64Index([240378], dtype='int64'),
#  'en_december_twelfth_movement': Int64Index([169175], dtype='int64'),
#  'en_conk_out': Int64Index([143143], dtype='int64'),
#  'en_runbox': Int64Index([548685], dtype='int64'),
#  'en_treaty_on_the_prohibition_of_anti-satellite_weapons_and_on_ways_to_ensure_the_immunity_of_space_objects': Int64Index([655317], dtype='int64'),
#  'en_gerardia': Int64Index([269956], dtype='int64'),
#  'en_it\xe2\x80\x99s_not_worth_a_hill_of_bean': Int64Index([341084], dtype='int64'),
#  'en_cleveland_orchestra': Int64Index([126331], dtype='int64'),
#  'en_diego_garcia': Int64Index([180446], dtype='int64'),
#  'en_magellanic_horned_owl': Int64Index([389928], dtype='int64'),
#  'en_committee_on_asean_youth_cooperation': Int64Index([135363], dtype='int64'),
#  'en_argyripnus_atlanticus': Int64Index([40460], dtype='int64'),
#  'en_yobidashi': Int64Index([708787, 708788, 708789], dtype='int64'),
#  'en_jujuy': Int64Index([352020], dtype='int64'),
#  'en_kodagu': Int64Index([359736], dtype='int64'),
#  'en_bare_metal_recovery': Int64Index([59975], dtype='int64'),
#  'en_warren_harding': Int64Index([688912], dtype='int64'),
#  'en_court_records_unit': Int64Index([153183], dtype='int64'),
#  'en_cape_air': Int64Index([101722], dtype='int64'),
#  'en_tim_tebow': Int64Index([645980], dtype='int64'),
#  'en_roy_rossell\xc3\xb3': Int64Index([546892], dtype='int64'),
#  'en_photophosphorylation': Int64Index([480561, 480562], dtype='int64'),
#  'en_avant-garde': Int64Index([53030, 53032, 53033, 53034, 53035], dtype='int64'),
#  'en_exhumation': Int64Index([225249], dtype='int64'),
#  'en_water_reservoirs': Int64Index([690528, 690529], dtype='int64'),
#  'en_white_riot': Int64Index([695850], dtype='int64'),
#  'en_mero\xc3\xab': Int64Index([407771], dtype='int64'),
#  'en_synthetical': Int64Index([625726], dtype='int64'),
#  'en_nitpicky': Int64Index([437974], dtype='int64'),
#  'en_sorcerous': Int64Index([593400], dtype='int64'),
#  'en_book_of_judges': Int64Index([82248], dtype='int64'),
#  'en_statesman': Int64Index([606367, 606368, 606369], dtype='int64'),
#  'en_letter_of_appointment': Int64Index([373182], dtype='int64'),
#  'en_punta_del_este_communiqu\xc3\xa9': Int64Index([512136], dtype='int64'),
#  'en_rob_pilatus': Int64Index([542723], dtype='int64'),
#  'en_erismantheae': Int64Index([216554], dtype='int64'),
#  'en_ketuanan_melayu': Int64Index([356165], dtype='int64'),
#  'en_acoustic_detector': Int64Index([6684], dtype='int64'),
#  'en_regional_conference_on_small_arms': Int64Index([528102], dtype='int64'),
#  'en_garganay': Int64Index([262709, 262712], dtype='int64'),
#  'en_b\xc3\xa2g\xc3\xa9-le-ch\xc3\xa2tel': Int64Index([56545], dtype='int64'),
#  'en_as_i_am': Int64Index([44814], dtype='int64'),
#  'en_spisula_ovalis': Int64Index([600149], dtype='int64'),
#  'en_serbian_despotate': Int64Index([569977], dtype='int64'),
#  'en_ala_gallorum_indiana': Int64Index([18904], dtype='int64'),
#  'en_glutamate': Int64Index([276212], dtype='int64'),
#  'en_claire_windsor': Int64Index([124370], dtype='int64'),
#  'en_network_assistant': Int64Index([434564], dtype='int64'),
#  'en_john_starks': Int64Index([348195], dtype='int64'),
#  'en_exclusive_distribution_agreement': Int64Index([224414], dtype='int64'),
#  'en_rinchenia': Int64Index([540330], dtype='int64'),
#  'en_mardy_fish': Int64Index([396788], dtype='int64'),
#  'en_be_quiet': Int64Index([69932, 69933, 69934, 69935, 69936, 69937, 69938, 69939, 69940,
#              69941],
#             dtype='int64'),
#  'en_ptolemaic': Int64Index([510021], dtype='int64'),
#  'en_alcolea': Int64Index([20100], dtype='int64'),
#  'en_avellaneda': Int64Index([53111], dtype='int64'),
#  'en_andrew_martin': Int64Index([29704], dtype='int64'),
#  'en_l\xc3\xa9onin': Int64Index([371898], dtype='int64'),
#  'en_joint_united_nations_information_committee/non-governmental_programme_group_on_women_and_development': Int64Index([349125], dtype='int64'),
#  'en_dears': Int64Index([168234], dtype='int64'),
#  'en_why_england_slept': Int64Index([696741], dtype='int64'),
#  'en_pastry_dough': Int64Index([469107, 469108], dtype='int64'),
#  'en_so_sick': Int64Index([594148], dtype='int64'),
#  'en_genus_cerastes': Int64Index([266573, 266574, 266575], dtype='int64'),
#  'en_water_knot': Int64Index([690295], dtype='int64'),
#  'en_margarine': Int64Index([396912, 396913, 396914, 396915], dtype='int64'),
#  'en_british_mandate': Int64Index([89179], dtype='int64'),
#  'en_undp/norway_trust_fund_for_the_special_plan_of_economic_cooperation_for_central_america': Int64Index([666462], dtype='int64'),
#  'en_m\xc3\xa9tal_hurlant': Int64Index([408489], dtype='int64'),
#  'en_regional_implementation_officer': Int64Index([528296], dtype='int64'),
#  'en_regional_knowledge_acquisition_forum': Int64Index([528366], dtype='int64'),
#  'en_probation_period': Int64Index([503019], dtype='int64'),
#  'en_special_representative_for_the_promotion_of_the_united_nations_decade_of_disabled_persons': Int64Index([598031], dtype='int64'),
#  'en_oxyathres_of_persia': Int64Index([460947], dtype='int64'),
#  'en_culture_of_prevention': Int64Index([160030], dtype='int64'),
#  'en_bjarni_benediktsson': Int64Index([75559], dtype='int64'),
#  'en_santiago_consensus': Int64Index([555078], dtype='int64'),
#  'en_codiaceae': Int64Index([130188], dtype='int64'),
#  'en_human_anatomy': Int64Index([311521], dtype='int64'),
#  'en_affrication': Int64Index([13471], dtype='int64'),
#  'en_assembled_binary_munitions_and_devices': Int64Index([46123], dtype='int64'),
#  'en_educational_software': Int64Index([203091, 203092], dtype='int64'),
#  'en_isopisthus_parvipinnis': Int64Index([340212], dtype='int64'),
#  'en_undernutrition': Int64Index([665760, 665761, 665762], dtype='int64'),
#  'en_horta_oest': Int64Index([309346], dtype='int64'),
#  'en_jink': Int64Index([346328], dtype='int64'),
#  'en_jino': Int64Index([346337], dtype='int64'),
#  'en_onan': Int64Index([450444], dtype='int64'),
#  'en_irc-hispano': Int64Index([338578], dtype='int64'),
#  'en_agricultural_resources': Int64Index([16560], dtype='int64'),
#  'en_t\xc3\xa1in_b\xc3\xb3_c\xc3\xbaailnge': Int64Index([627139], dtype='int64'),
#  'en_jinx': Int64Index([346346, 346347, 346348, 346349], dtype='int64'),
#  'en_chromis_punctipinnis': Int64Index([121681], dtype='int64'),
#  'en_la_uvita': Int64Index([367719], dtype='int64'),
#  'en_relapsing': Int64Index([529909], dtype='int64'),
#  'en_roger_glover': Int64Index([543548], dtype='int64'),
#  'en_undercutting': Int64Index([665512, 665513], dtype='int64'),
#  'en_san_pablo_church': Int64Index([554681], dtype='int64'),
#  'en_pacific_palisades': Int64Index([461631], dtype='int64'),
#  'en_folic_acid_deficiency': Int64Index([247744], dtype='int64'),
#  'en_geostrategy': Int64Index([269825], dtype='int64'),
#  'en_music_appreciation_hour': Int64Index([426080], dtype='int64'),
#  'en_minuartia': Int64Index([414420], dtype='int64'),
#  'en_inserted_material': Int64Index([327851], dtype='int64'),
#  'en_isthmian_league': Int64Index([340553], dtype='int64'),
#  'en_biscuit': Int64Index([74995, 74996, 74998, 75000, 75001], dtype='int64'),
#  'en_?jubo': Int64Index([351509], dtype='int64'),
#  'en_rabobank': Int64Index([517452], dtype='int64'),
#  'en_jean-baptiste_lamarck': Int64Index([344513], dtype='int64'),
#  'en_agate_fossil_beds_national_monument': Int64Index([14802], dtype='int64'),
#  'en_thoracic': Int64Index([642340, 642342, 642343, 642344, 642345], dtype='int64'),
#  'en_cacert.org': Int64Index([96820], dtype='int64'),
#  'en_h\xc3\xa1rbar\xc3\xb0slj\xc3\xb3\xc3\xb0': Int64Index([293787], dtype='int64'),
#  'en_port-valais': Int64Index([495025], dtype='int64'),
#  'en_andr\xc3\xa9_marty': Int64Index([29559], dtype='int64'),
#  'en_abyssinian_ground-thrush': Int64Index([3583], dtype='int64'),
#  'en_tetsu_katayama': Int64Index([636431], dtype='int64'),
#  'en_ill-considered': Int64Index([317449], dtype='int64'),
#  'en_be_on_leave': Int64Index([69785], dtype='int64'),
#  'en_united_nations_interagency_gender_group': Int64Index([668994], dtype='int64'),
#  'en_cysts': Int64Index([163402], dtype='int64'),
#  'en_insubstantial': Int64Index([329161, 329162, 329163], dtype='int64'),
#  'en_world_conservation_monitoring_centre': Int64Index([703995, 703996], dtype='int64'),
#  'en_office_for_the_coordination_of_humanitarian_assistance': Int64Index([447768], dtype='int64'),
#  'en_jewison': Int64Index([345942], dtype='int64'),
#  'en_dempsey': Int64Index([174132], dtype='int64'),
#  'en_atonement': Int64Index([49394, 49395, 49396, 49397, 49399, 49400], dtype='int64'),
#  'en_year_of_the_four_emperors': Int64Index([707816], dtype='int64'),
#  'en_non_phixion': Int64Index([439707], dtype='int64'),
#  'en_rupert_riedl': Int64Index([549149], dtype='int64'),
#  'en_pedro_almod\xc3\xb3var': Int64Index([472478], dtype='int64'),
#  'en_acharya': Int64Index([5994], dtype='int64'),
#  'en_franz_schreker': Int64Index([254108], dtype='int64'),
#  'en_drift_net': Int64Index([194671], dtype='int64'),
#  'en_solomon_mamaloni': Int64Index([591985], dtype='int64'),
#  'en_giant_wild_goose_pagoda': Int64Index([272207], dtype='int64'),
#  'en_sean_marks': Int64Index([562563], dtype='int64'),
#  'en_leonardo_dicaprio': Int64Index([371795], dtype='int64'),
#  'en_breathe_out': Int64Index([87514, 87515], dtype='int64'),
#  'en_nomad': Int64Index([438856, 438857], dtype='int64'),
#  'en_hyperimmune_serum': Int64Index([314557, 314558], dtype='int64'),
#  'en_congress_of_the_afro-asian_peoples\xe2\x80\x99_solidarity_organization': Int64Index([142875], dtype='int64'),
#  'en_women_fund_for_economic_empowerment': Int64Index([701391], dtype='int64'),
#  'en_eulophia': Int64Index([219799], dtype='int64'),
#  'en_memorandum_of_understanding_on_the_conservation_and_management_of_marine_turtles_and_their_habitats_of_the_indian_ocean_and_south-east_asia': Int64Index([406445], dtype='int64'),
#  'en_bagua_province': Int64Index([56666], dtype='int64'),
#  'en_homoeroticism': Int64Index([307395], dtype='int64'),
#  'en_dead_letter': Int64Index([167845], dtype='int64'),
#  'en_noir': Int64Index([438703], dtype='int64'),
#  'en_catalunya_r\xc3\xa0dio': Int64Index([107785], dtype='int64'),
#  'en_east-west_relations': Int64Index([200333], dtype='int64'),
#  'en_welser': Int64Index([693186], dtype='int64'),
#  'en_noia': Int64Index([438694, 438695], dtype='int64'),
#  'en_defecation_reflex': Int64Index([171142, 171143], dtype='int64'),
#  'en_lina_radke': Int64Index([376629], dtype='int64'),
#  'en_sawmilling': Int64Index([557077, 557078], dtype='int64'),
#  'en_kororaa': Int64Index([360198], dtype='int64'),
#  'en_oxidizer': Int64Index([460882, 460883], dtype='int64'),
#  'en_nondurable_good': Int64Index([439271], dtype='int64'),
#  'en_ageneiosus_melanopogon': Int64Index([15127], dtype='int64'),
#  'en_south_african_grand_prix': Int64Index([594886], dtype='int64'),
#  'en_artillery_fire': Int64Index([43556], dtype='int64'),
#  'en_gabbroic_complex': Int64Index([260555], dtype='int64'),
#  'en_vociferation': Int64Index([685290, 685291, 685292, 685293, 685294, 685295, 685296, 685297], dtype='int64'),
#  'en_george_porter': Int64Index([269501], dtype='int64'),
#  'en_oxidized': Int64Index([460878], dtype='int64'),
#  'en_germanium_tetrahydride': Int64Index([270180, 270181, 270182, 270183], dtype='int64'),
#  'en_lynyrd_skynyrd': Int64Index([388350], dtype='int64'),
#  'en_richard_strauss': Int64Index([539137], dtype='int64'),
#  'en_unicef_house_gift_shop': Int64Index([667721], dtype='int64'),
#  'en_aldeanueva_de_figueroa': Int64Index([20165], dtype='int64'),
#  'en_battle_of_the_santa_cruz_islands': Int64Index([63345], dtype='int64'),
#  'en_teacher_autonomy': Int64Index([631637, 631638, 631639], dtype='int64'),
#  'en_tropical_cyclone_landfall': Int64Index([658107], dtype='int64'),
#  'en_shakespeare_in_love': Int64Index([573239], dtype='int64'),
#  'en_dynamic_model': Int64Index([198676], dtype='int64'),
#  'en_dodger': Int64Index([189727, 189729, 189730, 189731], dtype='int64'),
#  'en_disarmament_agreements_and_negotiations_-_the_economic_dimension': Int64Index([183717], dtype='int64'),
#  'en_spend': Int64Index([598927, 598928, 598929, 598937, 598938, 598939, 598940, 598941,
#              598942, 598943, 598944, 598947, 598948, 598959, 598961, 598962,
#              598964, 598965, 598966, 598967],
#             dtype='int64'),
#  'en_like_a_train': Int64Index([375816, 375817, 375818, 375819, 375820, 375821], dtype='int64'),
#  'en_african_council_for_sustainable_health_development': Int64Index([13884], dtype='int64'),
#  'en_import_levies': Int64Index([319937], dtype='int64'),
#  'en_river_clyde': Int64Index([541477], dtype='int64'),
#  'en_natzweiler-struthof': Int64Index([431430], dtype='int64'),
#  'en_echinotrix_calamaris': Int64Index([200978], dtype='int64'),
#  'en_international_consultative_forum_on_education_for_all': Int64Index([332944], dtype='int64'),
#  'en_software_and_support_for_population_data_processing_project': Int64Index([590621], dtype='int64'),
#  'en_biota': Int64Index([74525, 74526], dtype='int64'),
#  'en_moving_titles,_layered': Int64Index([423238], dtype='int64'),
#  'en_valverdejo': Int64Index([677406], dtype='int64'),
#  'en_title-page': Int64Index([646818], dtype='int64'),
#  'en_imagine_coexistence': Int64Index([318089], dtype='int64'),
#  'en_loggia': Int64Index([381436], dtype='int64'),
#  'en_fossorochromis_rostratus': Int64Index([252067], dtype='int64'),
#  'en_toxic_trace_pollutants': Int64Index([651192], dtype='int64'),
#  'en_emil_h\xc3\xbcbner': Int64Index([208533], dtype='int64'),
#  'en_together_with_someone': Int64Index([647574, 647575], dtype='int64'),
#  'en_bali_road_map': Int64Index([57535], dtype='int64'),
#  'en_ch\xc3\xa2teau_de_fontainebleau': Int64Index([115637], dtype='int64'),
#  'en_solid_waste': Int64Index([591862], dtype='int64'),
#  'en_heat-producing': Int64Index([298133], dtype='int64'),
#  'en_safe_abortion': Int64Index([550773, 550774], dtype='int64'),
#  'en_orea': Int64Index([455139], dtype='int64'),
#  'en_m\xc3\xbchledorf': Int64Index([424092], dtype='int64'),
#  'en_boundary': Int64Index([84171, 84172, 84174, 84175, 84176, 84178, 84180, 84181, 84182,
#              84186, 84187, 84188, 84189, 84195, 84197, 84198, 84202, 84210],
#             dtype='int64'),
#  'en_financial_systems_steering_committee': Int64Index([240695], dtype='int64'),
#  'en_list_of_constitutional_courts': Int64Index([378442, 378443], dtype='int64'),
#  'en_oreo': Int64Index([455254], dtype='int64'),
#  'en_vanessa_bell': Int64Index([677568], dtype='int64'),
#  'en_non-operating_costs': Int64Index([439666], dtype='int64'),
#  'en_tanzania_media_women_association': Int64Index([629497], dtype='int64'),
#  'en_roberto_fern\xc3\xa1ndez_bonillo': Int64Index([542392], dtype='int64'),
#  'en_val_ramos': Int64Index([677209], dtype='int64'),
#  'en_intervention_currency': Int64Index([336148], dtype='int64'),
#  'en_gestalgar': Int64Index([270495], dtype='int64'),
#  'en_richie_hawtin': Int64Index([539201], dtype='int64'),
#  'en_one,_two,_three,_four': Int64Index([451035], dtype='int64'),
#  'en_febricity': Int64Index([235163], dtype='int64'),
#  'en_effortlessly': Int64Index([203956, 203957, 203958], dtype='int64'),
#  'en_bullocks': Int64Index([92920, 92938], dtype='int64'),
#  'en_environment_support_section': Int64Index([214273], dtype='int64'),
#  'en_olive_tree': Int64Index([449930, 449932, 449934, 449936, 449938], dtype='int64'),
#  'en_volume_reduction_and_chemical_extraction_technology': Int64Index([685744], dtype='int64'),
#  'en_commercial': Int64Index([134736, 134750, 134766, 134818, 134838, 134844], dtype='int64'),
#  'en_hear_music': Int64Index([297666], dtype='int64'),
#  'en_enabling_mechanism': Int64Index([209624, 209625], dtype='int64'),
#  'en_gerrit_rietveld': Int64Index([270413], dtype='int64'),
#  'en_unjspf_beneficiary': Int64Index([670658], dtype='int64'),
#  'en_plectorhinchus_cinctus': Int64Index([488458], dtype='int64'),
#  'en_lara_croft': Int64Index([365447], dtype='int64'),
#  'en_lymphosarcoma': Int64Index([388301], dtype='int64'),
#  'en_working_party_on_computers': Int64Index([703215], dtype='int64'),
#  'en_duodecimal_digit': Int64Index([197612], dtype='int64'),
#  'en_sublunar': Int64Index([616274, 616275], dtype='int64'),
#  'en_oxherd': Int64Index([460819], dtype='int64'),
#  'en_lice': Int64Index([374429, 374511, 374512, 374513, 374514], dtype='int64'),
#  'en_dreadless': Int64Index([194061, 194062, 194063], dtype='int64'),
#  'en_robertson_islands': Int64Index([542520], dtype='int64'),
#  'en_with_young': Int64Index([700733, 700734, 700735, 700736, 700737, 700738, 700739], dtype='int64'),
#  'en_lick': Int64Index([374564, 374565, 374566, 374567, 374569, 374581, 374589, 374590,
#              374591, 374592, 374593, 374594, 374595, 374597, 374598, 374599,
#              374600, 374602, 374603, 374604, 374605, 374609],
#             dtype='int64'),
#  'en_qizil_qum': Int64Index([514775, 514776], dtype='int64'),
#  'en_non-battle_casualties': Int64Index([439046], dtype='int64'),
#  'en_schist_soils': Int64Index([558813], dtype='int64'),
#  'en_haccp': Int64Index([290693], dtype='int64'),
#  'en_istle': Int64Index([340575, 340576, 340577, 340578], dtype='int64'),
#  'en_universidad_san_mart\xc3\xadn_de_porres': Int64Index([670392], dtype='int64'),
#  'en_grigory_zinoviev': Int64Index([285275], dtype='int64'),
#  'en_xining': Int64Index([706842], dtype='int64'),
#  'en_family_cariamidae': Int64Index([231345, 231346], dtype='int64'),
#  'en_m-1_rifle': Int64Index([388509, 388510, 388511, 388513], dtype='int64'),
#  'en_information_circular': Int64Index([325505], dtype='int64'),
#  'en_sagogn': Int64Index([551187], dtype='int64'),
#  'en_l\xc3\xa9on_bakst': Int64Index([371823], dtype='int64'),
#  'en_validation_test': Int64Index([676949], dtype='int64'),
#  'en_standing_conference_on_disarmament': Int64Index([604903], dtype='int64'),
#  'en_invercargill': Int64Index([337415], dtype='int64'),
#  'en_texas_independence_day': Int64Index([636491], dtype='int64'),
#  'en_lefetamine': Int64Index([370405], dtype='int64'),
#  'en_right_to_stand_for_election': Int64Index([540101], dtype='int64'),
#  'en_piz_buin': Int64Index([485571], dtype='int64'),
#  'en_omnis_studio': Int64Index([450320], dtype='int64'),
#  'en_la_almunia_de_do\xc3\xb1a_godina': Int64Index([361343], dtype='int64'),
#  'en_bank_supervisors': Int64Index([59186, 59187], dtype='int64'),
#  'en_australian_centre_for_international_agriculture_research': Int64Index([51815], dtype='int64'),
#  'en_casualties': Int64Index([107640, 107642], dtype='int64'),
#  'en_rocka_rolla': Int64Index([542851], dtype='int64'),
#  'en_ground_for_invalidating,_terminating,_withdrawing_from_or_suspending_the_operation_of_a_treaty': Int64Index([286148], dtype='int64'),
#  'en_national_alliance': Int64Index([429956], dtype='int64'),
#  'en_pedro_santana': Int64Index([472652], dtype='int64'),
#  'en_european_agreement_on_the_protection_of_television_broadcasts': Int64Index([220461], dtype='int64'),
#  'en_alex_kidd_in_shinobi_world': Int64Index([21090], dtype='int64'),
#  'en_unfreeze': Int64Index([667355, 667356, 667357, 667358, 667359, 667360, 667361, 667362,
#              667363, 667364],
#             dtype='int64'),
#  'en_natural_language_searching': Int64Index([431235], dtype='int64'),
#  'en_nueva_esparta': Int64Index([443429], dtype='int64'),
#  'en_sylvius_leopold_weiss': Int64Index([624980], dtype='int64'),
#  'en_franciacorta': Int64Index([253280], dtype='int64'),
#  'en_weather_bureau': Int64Index([691871, 691872], dtype='int64'),
#  'en_centzonuitznaua': Int64Index([111600], dtype='int64'),
#  'en_nephron': Int64Index([433800, 433801], dtype='int64'),
#  'en_system_of_rules': Int64Index([626044], dtype='int64'),
#  'en_ecologic': Int64Index([201217], dtype='int64'),
#  'en_regional_directorate_for_europe_and_the_commonwealth_of_independent_states': Int64Index([528177], dtype='int64'),
#  'en_chionodraco_rastrospinosus': Int64Index([119623], dtype='int64'),
#  'en_m\xc3\xa1ximo_g\xc3\xb3mez': Int64Index([402178, 402179], dtype='int64'),
#  'en_all_fours': Int64Index([22654], dtype='int64'),
#  'en_pseudo-sophisticated': Int64Index([509387, 509388], dtype='int64'),
#  'en_eighty-seven': Int64Index([204546], dtype='int64'),
#  'en_optimism': Int64Index([453729], dtype='int64'),
#  'en_accidental_release_to_the_environment': Int64Index([4586], dtype='int64'),
#  'en_edwyn_burnaby': Int64Index([203544], dtype='int64'),
#  'en_optimist': Int64Index([453738, 453739], dtype='int64'),
#  'en_mothership': Int64Index([421548, 421549], dtype='int64'),
#  'en_pleoticus_muelleri': Int64Index([488688], dtype='int64'),
#  'en_semi': Int64Index([568247, 568248], dtype='int64'),
#  'en_awrong': Int64Index([54102], dtype='int64'),
#  'en_peppermint_patty': Int64Index([474608], dtype='int64'),
#  'en_andrew_lincoln': Int64Index([29700], dtype='int64'),
#  'en_flinchy': Int64Index([245335, 245336], dtype='int64'),
#  'en_idiomatical': Int64Index([316471, 316472], dtype='int64'),
#  'en_industrial_park': Int64Index([324207, 324208, 324209], dtype='int64'),
#  'en_real_uni\xc3\xb3n': Int64Index([522948], dtype='int64'),
#  'en_caster': Int64Index([107218, 107219, 107220], dtype='int64'),
#  'en_bianca_castafiore': Int64Index([72094], dtype='int64'),
#  'en_euryale_ferox': Int64Index([222093], dtype='int64'),
#  'en_stenographical': Int64Index([608055], dtype='int64'),
#  'en_luciano_comella': Int64Index([385941], dtype='int64'),
#  'en_liftin': Int64Index([375096, 375097, 375098, 375099, 375114, 375115, 375116, 375117,
#              375118, 375119, 375120, 375121, 375122, 375123],
#             dtype='int64'),
#  'en_unep_sasakawa_environment_prize': Int64Index([666837], dtype='int64'),
#  'en_freedom_of_mobile_multimedia_access': Int64Index([254742], dtype='int64'),
#  'en_voting_without_meeting': Int64Index([686158], dtype='int64'),
#  'en_heritage_preservation': Int64Index([301348, 301349], dtype='int64'),
#  'en_disgruntle': Int64Index([185413, 185414, 185417], dtype='int64'),
#  'en_love_wave': Int64Index([385046, 385047], dtype='int64'),
#  'en_shaba': Int64Index([572744, 572745, 572746, 572747, 572750, 572752, 572753, 572754,
#              572758, 572759, 572760],
#             dtype='int64'),
#  'en_compound_interest_rate': Int64Index([139199, 139200], dtype='int64'),
#  'en_disburse': Int64Index([184020, 184022, 184023, 184024, 184026, 184034], dtype='int64'),
#  'en_cielito_lindo': Int64Index([122515], dtype='int64'),
#  'en_resilience_of_a_community': Int64Index([534772], dtype='int64'),
#  'en_be_disrespectful_to': Int64Index([66150], dtype='int64'),
#  'en_rootstalk': Int64Index([544915], dtype='int64'),
#  'en_critical_incident': Int64Index([156725], dtype='int64'),
#  'en_shabu': Int64Index([572785], dtype='int64'),
#  'en_soil_conditioners': Int64Index([590782], dtype='int64'),
#  'en_life-span': Int64Index([374988], dtype='int64'),
#  'en_pierre_amine_gemayel': Int64Index([482560], dtype='int64'),
#  'en_hotlist': Int64Index([309862, 309863, 309864], dtype='int64'),
#  'en_termites': Int64Index([635336, 635337, 635338, 635339], dtype='int64'),
#  'en_oiran': Int64Index([448964, 448965, 448966, 448967, 448968, 448969, 448970, 448971,
#              448972, 448973, 448974, 448975, 448976, 448977, 448978, 448979,
#              448980],
#             dtype='int64'),
#  'en_cost_of_living': Int64Index([151344, 151345, 151346, 151347, 151351, 151352], dtype='int64'),
#  'en_maximum_transmission_unit': Int64Index([402242], dtype='int64'),
#  'en_beasain': Int64Index([64631], dtype='int64'),
#  'en_argyrocottus_zanderi': Int64Index([40461], dtype='int64'),
#  'en_drag_alon': Int64Index([193218], dtype='int64'),
#  'en_naughty': Int64Index([431447, 431449, 431450, 431451, 431452, 431453, 431454, 431455,
#              431456],
#             dtype='int64'),
#  'en_socioprofessional_category': Int64Index([590066], dtype='int64'),
#  'en_neorossia_caroli': Int64Index([433630], dtype='int64'),
#  'en_complacence': Int64Index([138547, 138548, 138549, 138550], dtype='int64'),
#  'en_tropical_wood': Int64Index([658194], dtype='int64'),
#  'en_associative': Int64Index([47326, 47327], dtype='int64'),
#  'en_valencia_city': Int64Index([676758], dtype='int64'),
#  'en_with_more_than_one_valence': Int64Index([700600], dtype='int64'),
#  'en_complacency': Int64Index([138551, 138552], dtype='int64'),
#  'en_chubut_river': Int64Index([121980], dtype='int64'),
#  'en_pholis_gunnellus': Int64Index([480069], dtype='int64'),
#  'en_coordinating_committee_for_refugees': Int64Index([148402], dtype='int64'),
#  'en_christmas': Int64Index([121470, 121471, 121472], dtype='int64'),
#  'en_disk_duplication': Int64Index([185879], dtype='int64'),
#  'en_pefc_council': Int64Index([472946], dtype='int64'),
#  'en_augsburg_confession': Int64Index([51293], dtype='int64'),
#  'en_government': Int64Index([280210, 280235, 280242, 280265, 280284, 280285, 280286, 280287,
#              280289, 280296, 280306, 280307, 280349, 280356, 280362],
#             dtype='int64'),
#  'en_auctorial': Int64Index([50782], dtype='int64'),
#  'en_niggardliness': Int64Index([437089, 437090, 437091], dtype='int64'),
#  'en_maritime_command_operational_training_exercise': Int64Index([397936], dtype='int64'),
#  'en_georg_cantor': Int64Index([269239], dtype='int64'),
#  'en_poverty_eradication,_employment_and_youth_branch': Int64Index([496854], dtype='int64'),
#  'en_center_for_justice_and_international_law': Int64Index([110718], dtype='int64'),
#  'en_disposed_to': Int64Index([186695], dtype='int64'),
#  'en_sebastian_faulks': Int64Index([563205], dtype='int64'),
#  'en_lincoln_child': Int64Index([376676], dtype='int64'),
#  'en_sony_ericsson_t610': Int64Index([593010], dtype='int64'),
#  'en_batz-sur-mer': Int64Index([63489], dtype='int64'),
#  'en_bloodstain': Int64Index([78565], dtype='int64'),
#  'en_green_cochoa': Int64Index([284147], dtype='int64'),
#  'en_training_adviser': Int64Index([652482], dtype='int64'),
#  'en_canadian_association_of_latin_american_studies': Int64Index([100050], dtype='int64'),
#  'en_monotonous': Int64Index([419292, 419293, 419294, 419295, 419296, 419297, 419299], dtype='int64'),
#  'en_fran\xc3\xa7ois_rude': Int64Index([253719], dtype='int64'),
#  'en_environmental_information': Int64Index([213941], dtype='int64'),
#  'en_bitterfeld': Int64Index([75345], dtype='int64'),
#  'en_id_software': Int64Index([316753], dtype='int64'),
#  'en_academic_department': Int64Index([3737], dtype='int64'),
#  'en_off_and_on': Int64Index([447401], dtype='int64'),
#  'en_district_administrative_group': Int64Index([187930], dtype='int64'),
#  'en_hyundai_tiburon': Int64Index([315283], dtype='int64'),
#  'en_millinery': Int64Index([412794], dtype='int64'),
#  'en_battering_ram': Int64Index([62581, 62582, 62583], dtype='int64'),
#  'en_ranting': Int64Index([520593, 520594, 520595], dtype='int64'),
#  'en_ac_-_powered': Int64Index([6731], dtype='int64'),
#  'en_bacchus_festival': Int64Index([55104], dtype='int64'),
#  'en_roberto_gonz\xc3\xa1lez_nieves': Int64Index([542404], dtype='int64'),
#  'en_a\xc3\xafcirits-camou-suhast': Int64Index([17227], dtype='int64'),
#  'en_family_labridae': Int64Index([231767, 231768], dtype='int64'),
#  'en_talent_scout': Int64Index([628428, 628429], dtype='int64'),
#  'en_minahasa': Int64Index([413088], dtype='int64'),
#  'en_ganders': Int64Index([262093, 262094, 262095, 262096], dtype='int64'),
#  'en_beta_pegasi': Int64Index([71282], dtype='int64'),
#  'en_cutting_areas': Int64Index([162218, 162219], dtype='int64'),
#  'en_spanish_royal_guard': Int64Index([596532], dtype='int64'),
#  'en_dar\xc3\xado_vittori': Int64Index([165581], dtype='int64'),
#  'en_motile': Int64Index([421594, 421595], dtype='int64'),
#  'en_coffea_congensis': Int64Index([130436], dtype='int64'),
#  'en_strawberry_mark': Int64Index([612644], dtype='int64'),
#  'en_placebo-assigned_group': Int64Index([485658], dtype='int64'),
#  'en_video_display_unit_work': Int64Index([681873], dtype='int64'),
#  'en_air_mauritius': Int64Index([18140], dtype='int64'),
#  'en_rockefeller_center': Int64Index([542890], dtype='int64'),
#  'en_convention_on_the_unification_of_the_law_relating_to_bills_of_exchange_and_promissory_notes,_and_uniform_regulations': Int64Index([147416], dtype='int64'),
#  'en_voodoo_glow_skulls': Int64Index([686004], dtype='int64'),
#  'en_chondrostereum': Int64Index([120765], dtype='int64'),
#  'en_dol_guldur': Int64Index([190125], dtype='int64'),
#  'en_quadraphony': Int64Index([514860], dtype='int64'),
#  'en_quarryhill_botanic_garden': Int64Index([515442], dtype='int64'),
#  'en_culture_of_fiji': Int64Index([159995], dtype='int64'),
#  'en_own_value': Int64Index([460733], dtype='int64'),
#  'en_mucor_miehei': Int64Index([423740, 423741], dtype='int64'),
#  'en_indication': Int64Index([323177, 323178, 323179, 323180, 323181, 323182, 323183, 323184,
#              323185, 323186, 323187, 323188, 323189, 323190, 323191, 323192,
#              323193],
#             dtype='int64'),
#  'en_ia-pc': Int64Index([315437], dtype='int64'),
#  'en_see_bobada': Int64Index([564979, 564980], dtype='int64'),
#  'en_tragedian': Int64Index([652305, 652306], dtype='int64'),
#  'en_pleased': Int64Index([488285, 488286, 488287, 488288, 488289, 488291, 488292, 488293], dtype='int64'),
#  'en_the_aeroplane_flies_high': Int64Index([637104], dtype='int64'),
#  'en_aqueous_cleaner': Int64Index([38173], dtype='int64'),
#  'en_delta_works': Int64Index([173149], dtype='int64'),
#  'en_pleaser': Int64Index([488309], dtype='int64'),
#  'en_cellini': Int64Index([110295], dtype='int64'),
#  'en_citro\xc3\xabn_c-buggy': Int64Index([123614], dtype='int64'),
#  'en_plan_for_prevention_and_rehabilitation_of_drug_addicts': Int64Index([486395], dtype='int64'),
#  'en_superdisk': Int64Index([619996], dtype='int64'),
#  'en_philippine_literature_in_spanish': Int64Index([479682], dtype='int64'),
#  'en_farsala': Int64Index([233478], dtype='int64'),
#  'en_blenio': Int64Index([77577], dtype='int64'),
#  'en_climate_simulation_model': Int64Index([126659], dtype='int64'),
#  'en_matric': Int64Index([401295], dtype='int64'),
#  'en_library_and_reference_unit': Int64Index([374358], dtype='int64'),
#  'en_matriz': Int64Index([401338], dtype='int64'),
#  'en_sotresgudo': Int64Index([594240], dtype='int64'),
#  'en_matrix': Int64Index([401328, 401329], dtype='int64'),
#  'en_advanced_composition_explorer': Int64Index([11451], dtype='int64'),
#  'en_split_bar': Int64Index([600488], dtype='int64'),
#  'en_become_less': Int64Index([65619, 65620, 65621, 65623], dtype='int64'),
#  'en_on_draft': Int64Index([450692, 450693], dtype='int64'),
#  'en_improver': Int64Index([320363, 320368], dtype='int64'),
#  'en_c.f._os_belenenses': Int64Index([112728], dtype='int64'),
#  'en_see_del_exterior': Int64Index([565267], dtype='int64'),
#  'en_trapped-radiation_regions': Int64Index([654389, 654390], dtype='int64'),
#  'en_international_penal_and_penitentiary_foundation': Int64Index([334211], dtype='int64'),
#  'en_storage_disorders': Int64Index([611324, 611325, 611326, 611327], dtype='int64'),
#  'en_overview': Int64Index([460388, 460389, 460390, 460392, 460393, 460394, 460395, 460396], dtype='int64'),
#  'en_regional_administrative_radio_conference': Int64Index([527904], dtype='int64'),
#  'en_improved': Int64Index([320320], dtype='int64'),
#  'en_magnus_hirschfeld': Int64Index([390425], dtype='int64'),
#  'en_cannes_film_festival': Int64Index([100954], dtype='int64'),
#  'en_anthoxanthum': Int64Index([33171], dtype='int64'),
#  'en_prism_spectroscope': Int64Index([502468, 502469], dtype='int64'),
#  'en_now_presenting_panel': Int64Index([442819], dtype='int64'),
#  'en_olmsted': Int64Index([449998], dtype='int64'),
#  'en_national_museum': Int64Index([430541, 430542], dtype='int64'),
#  'en_integrated_industrial_promotion_programme': Int64Index([329623], dtype='int64'),
#  'en_single_cabin_pick-up': Int64Index([581420], dtype='int64'),
#  'en_emacs_lisp': Int64Index([207535], dtype='int64'),
#  'en_saint_joseph': Int64Index([551700, 551701, 551702, 551703, 551705], dtype='int64'),
#  'en_ad_hoc_working_group_of_experts_on_transnational_corporations_and_transborder_data_flows': Int64Index([9526], dtype='int64'),
#  'en_dartford_warbler': Int64Index([165902, 165903, 165904, 165905], dtype='int64'),
#  'en_antonio_p\xc3\xa9rez': Int64Index([34696], dtype='int64'),
#  'en_woody_species': Int64Index([702130, 702131], dtype='int64'),
#  'en_coralliophila_meyendorffi': Int64Index([149061], dtype='int64'),
#  'en_annals_of_internal_medicine': Int64Index([31514], dtype='int64'),
#  'en_caelorinchus_biclinozonalis': Int64Index([97165], dtype='int64'),
#  'en_neisse_university': Int64Index([433135], dtype='int64'),
#  'en_daniel_hadad': Int64Index([165106], dtype='int64'),
#  'en_combat_sport': Int64Index([133221], dtype='int64'),
#  'en_consumer_durables': Int64Index([144961], dtype='int64'),
#  'en_punching_bag': Int64Index([511880, 511881], dtype='int64'),
#  'en_never_knew_love_like_this_before': Int64Index([435147], dtype='int64'),
#  'en_put_to_pasture': Int64Index([514001, 514002], dtype='int64'),
#  'en_waiting_line': Int64Index([687055], dtype='int64'),
#  'en_as_ever': Int64Index([44533], dtype='int64'),
#  'en_suppressing_fire': Int64Index([621117], dtype='int64'),
#  'en_brasilia_declaration': Int64Index([86174], dtype='int64'),
#  'en_anne_of_bohemia': Int64Index([31667], dtype='int64'),
#  'en_upper_level_ontology': Int64Index([673678], dtype='int64'),
#  'en_chelydridae': Int64Index([116691, 116692, 116693, 116694, 116695], dtype='int64'),
#  'en_liqueur': Int64Index([377922, 377923, 377924, 377925, 377926], dtype='int64'),
#  'en_belisha': Int64Index([68056], dtype='int64'),
#  'en_bit_specification': Int64Index([75307], dtype='int64'),
#  'en_geraint_thomas': Int64Index([269884], dtype='int64'),
#  'en_inigo_campioni': Int64Index([326429], dtype='int64'),
#  'en_bouguer_gravity_contour_map': Int64Index([84044], dtype='int64'),
#  'en_tenrecidae': Int64Index([634680], dtype='int64'),
#  'en_humanitarian_relief_centre': Int64Index([311788], dtype='int64'),
#  'en_telescopium_telescopium': Int64Index([633506], dtype='int64'),
#  'en_pressure_sensitive_tape': Int64Index([500325], dtype='int64'),
#  'en_rutin': Int64Index([549774, 549775, 549776], dtype='int64'),
#  'en_sensitized': Int64Index([569266, 569267, 569268], dtype='int64'),
#  'en_chubby': Int64Index([121954, 121956, 121957, 121958, 121959, 121961, 121962, 121963,
#              121964, 121965, 121966, 121967, 121968, 121969, 121970, 121971,
#              121972, 121973],
#             dtype='int64'),
#  'en_margarida_of_savoy': Int64Index([396910], dtype='int64'),
#  'en_mincemeat': Int64Index([413147, 413148, 413149], dtype='int64'),
#  'en_fixed-weight_price_index': Int64Index([243284], dtype='int64'),
#  'en_rissole': Int64Index([541280, 541281], dtype='int64'),
#  'en_voluntary_sector': Int64Index([685871, 685872], dtype='int64'),
#  'en_ruth_brown': Int64Index([549708], dtype='int64'),
#  'en_bourg-la-reine': Int64Index([84350], dtype='int64'),
#  'en_albufera': Int64Index([19827], dtype='int64'),
#  'en_poinsettias': Int64Index([490214, 490215, 490216, 490217, 490218], dtype='int64'),
#  'en_wilusa': Int64Index([698610], dtype='int64'),
#  'en_mikania_scandens': Int64Index([411770], dtype='int64'),
#  'en_horned_dung_beetle': Int64Index([308861, 308862], dtype='int64'),
#  'en_enterprise_resource_planning': Int64Index([213069], dtype='int64'),
#  'en_chioma_ajunwa': Int64Index([119604], dtype='int64'),
#  'en_ferment': Int64Index([237088, 237089, 237090, 237091, 237092, 237109, 237110, 237111,
#              237112, 237113, 237114, 237115, 237116, 237129, 237133, 237134,
#              237135, 237136, 237137, 237138, 237139, 237140, 237141, 237143,
#              237144, 237145, 237146, 237147, 237148, 237150, 237151, 237152,
#              237153],
#             dtype='int64'),
#  'en_relleu': Int64Index([530657], dtype='int64'),
#  'en_kodomo_anime_and_manga': Int64Index([359762], dtype='int64'),
#  'en_domestic_jurisdiction_clause': Int64Index([190612], dtype='int64'),
#  'en_jervis_drummond': Int64Index([345520], dtype='int64'),
#  'en_party_of_bulgarian_social_democrats': Int64Index([468007], dtype='int64'),
#  'en_calliactis_parasitica': Int64Index([98556], dtype='int64'),
#  'en_university_of_virginia': Int64Index([670618], dtype='int64'),
#  'en_chigorod\xc3\xb3': Int64Index([118274], dtype='int64'),
#  'en_castell\xe2\x80\x99alfero': Int64Index([107173], dtype='int64'),
#  'en_scientific_symposium_on_space_communications_for_development': Int64Index([559771], dtype='int64'),
#  'en_amenhotep_ii': Int64Index([26279], dtype='int64'),
#  'en_basic_agreement_for_the_search_for_peace_by_political_means': Int64Index([61389], dtype='int64'),
#  'en_morris_swadesh': Int64Index([420916], dtype='int64'),
#  'en_enzyme_preparations': Int64Index([214425, 214426], dtype='int64'),
#  'en_parallax': Int64Index([465718], dtype='int64'),
#  'en_srv_resource_record': Int64Index([603303], dtype='int64'),
#  'en_technical_meeting_for_the_analysis_of_intraregional_trade_and_the_development_of_the_mining_and_metallurgical_sector': Int64Index([632562], dtype='int64'),
#  'en_herbert_pitman': Int64Index([301035], dtype='int64'),
#  'en_ad_hoc_group_of_experts_on_steel': Int64Index([9407], dtype='int64'),
#  'en_agricultural_societies': Int64Index([16577], dtype='int64'),
#  'en_united_nations_documentation_information_system': Int64Index([668791], dtype='int64'),
#  'en_formalin': Int64Index([250848, 250849], dtype='int64'),
#  'en_clippers': Int64Index([127025, 127027, 127028], dtype='int64'),
#  'en_departure': Int64Index([175069, 175070, 175071, 175072, 175073, 175074, 175075, 175076,
#              175078, 175080, 175081, 175082, 175083, 175084, 175085, 175086,
#              175087, 175088],
#             dtype='int64'),
#  'en_jo\xc3\xa3o_de_loureiro': Int64Index([346588], dtype='int64'),
#  'en_estonian_supercup': Int64Index([218574], dtype='int64'),
#  'en_nuclear,_biological_and_chemical_overpressure': Int64Index([443098, 443099], dtype='int64'),
#  'en_prades': Int64Index([497525], dtype='int64'),
#  'en_edss': Int64Index([202784], dtype='int64'),
#  'en_bakery_industry': Int64Index([57058, 57059, 57060, 57061], dtype='int64'),
#  'en_modal_auxiliary': Int64Index([416921, 416922, 416923], dtype='int64'),
#  'en_unscathed': Int64Index([672056, 672057], dtype='int64'),
#  'en_pilot_pen_corporation': Int64Index([483498], dtype='int64'),
#  'en_combustion_engine': Int64Index([133471, 133472], dtype='int64'),
#  'en_eastern_africa_police_chiefs_cooperation_organization': Int64Index([199977], dtype='int64'),
#  'en_british_shilling': Int64Index([89204, 89205], dtype='int64'),
#  'en_kirchnerism': Int64Index([358229], dtype='int64'),
#  'en_decebalus': Int64Index([169071], dtype='int64'),
#  'en_absolute_rule': Int64Index([2927], dtype='int64'),
#  'en_catastro_of_ensenada': Int64Index([107906], dtype='int64'),
#  'en_jack_in_office': Int64Index([341828], dtype='int64'),
#  'en_schilbe_mystus': Int64Index([558769], dtype='int64'),
#  'en_protection_operations_and_legal_advice_section': Int64Index([507294], dtype='int64'),
#  'en_aid_evaluation': Int64Index([17308], dtype='int64'),
#  'en_jane_badler': Int64Index([343235], dtype='int64'),
#  'en_ferromagnetism': Int64Index([237479], dtype='int64'),
#  'en_backhand': Int64Index([55479, 55480, 55481], dtype='int64'),
#  'en_santo_daime': Int64Index([555196], dtype='int64'),
#  'en_could': Int64Index([151710], dtype='int64'),
#  'en_ability_grouping': Int64Index([1715], dtype='int64'),
#  'en_kia_sportage': Int64Index([356623], dtype='int64'),
#  'en_sagina': Int64Index([551164], dtype='int64'),
#  'en_mecoptera': Int64Index([403801, 403802, 403803, 403804], dtype='int64'),
#  'en_gerardo_machado': Int64Index([269975], dtype='int64'),
#  'en_impolicy': Int64Index([319805], dtype='int64'),
#  'en_isherwood': Int64Index([339672], dtype='int64'),
#  'en_anchoret': Int64Index([28882], dtype='int64'),
#  'en_laccaria': Int64Index([361964], dtype='int64'),
#  'en_sofia_scicolone': Int64Index([590323], dtype='int64'),
#  'en_anchored': Int64Index([28881], dtype='int64'),
#  'en_film_producer': Int64Index([240046, 240047, 240048, 240049], dtype='int64'),
#  'en_colleague': Int64Index([131757, 131758, 131759, 131760, 131761, 131762, 131763, 131764,
#              131765, 131766, 131767, 131768, 131769, 131770, 131771, 131772,
#              131773, 131774, 131775, 131776],
#             dtype='int64'),
#  'en_united_nations_activities_against_apartheid': Int64Index([668449], dtype='int64'),
#  'en_marbach': Int64Index([396259], dtype='int64'),
#  'en_dna_probe': Int64Index([189164], dtype='int64'),
#  'en_unallocated_resources': Int64Index([664384], dtype='int64'),
#  'en_vinblastine': Int64Index([683165], dtype='int64'),
#  'en_vena_cystica': Int64Index([679202], dtype='int64'),
#  'en_reclining_chair': Int64Index([524291], dtype='int64'),
#  'en_apartment': Int64Index([35326, 35327, 35328, 35329, 35333, 35335, 35336, 35337, 35338,
#              35340, 35341],
#             dtype='int64'),
#  'en_anders_jahan_retzius': Int64Index([29237], dtype='int64'),
#  'en_4_x_4_station_wagon': Int64Index([352], dtype='int64'),
#  'en_wilson\xe2\x80\x99s_phalarope': Int64Index([698559, 698560, 698561, 698562, 698563, 698564, 698565, 698566,
#              698567, 698568, 698569, 698570],
#             dtype='int64'),
#  'en_party_of_hutu_emancipation_movement': Int64Index([468016], dtype='int64'),
#  'en_pick_withers': Int64Index([482025], dtype='int64'),
#  'en_comprehensive_and_integral_international_convention_on_protection_and_promotion_of_the_rights_and_dignity_of_persons_with_disabilities': Int64Index([139260], dtype='int64'),
#  'en_aesculapian': Int64Index([12827, 12828], dtype='int64'),
#  'en_child_prodigy': Int64Index([118555], dtype='int64'),
#  'en_sciacca': Int64Index([559566], dtype='int64'),
#  'en_bear_upon': Int64Index([64608, 64609], dtype='int64'),
#  'en_petersberg_tasks': Int64Index([477981], dtype='int64'),
#  'en_pollution_control': Int64Index([491913, 491918, 491923, 491924, 491925, 491926, 491933], dtype='int64'),
#  'en_antinutrient': Int64Index([33902], dtype='int64'),
#  'en_nancy_reagan': Int64Index([428734], dtype='int64'),
#  'en_phylloxera': Int64Index([480867, 480868, 480869], dtype='int64'),
#  'en_non-governmental_organizations_forum_on_the_female_child_of_today': Int64Index([439461], dtype='int64'),
#  'en_calorie': Int64Index([99109], dtype='int64'),
#  'en_caloric': Int64Index([99095, 99096, 99101, 99102], dtype='int64'),
#  'en_ukrainian': Int64Index([663676, 663677, 663678], dtype='int64'),
#  'en_jean_arp': Int64Index([344483, 344484], dtype='int64'),
#  'en_nose_and_tear_duct_related': Int64Index([441602], dtype='int64'),
#  'en_trachurus_spp': Int64Index([651525], dtype='int64'),
#  'en_flag_of_abkhazia': Int64Index([243562], dtype='int64'),
#  'en_violent_stream': Int64Index([683515], dtype='int64'),
#  'en_ian_mcdiarmid': Int64Index([315415], dtype='int64'),
#  'en_altenberg': Int64Index([24617], dtype='int64'),
#  'en_sigfrid_of_sweden': Int64Index([579356], dtype='int64'),
#  'en_signature': Int64Index([579629, 579630, 579632, 579633, 579635, 579636, 579637, 579638,
#              579642, 579643, 579645, 579646, 579648, 579649, 579650, 579651],
#             dtype='int64'),
#  'en_common_services_governance_and_infrastructure': Int64Index([136761], dtype='int64'),
#  'en_rules_of_procedure_of_the_inter-american_commercial_arbitration_commission': Int64Index([548274], dtype='int64'),
#  'en_ramona': Int64Index([519959], dtype='int64'),
#  'en_out_of_the_ordinary': Int64Index([458660, 458661, 458662, 458663, 458664, 458665, 458666, 458667], dtype='int64'),
#  'en_worker_performance': Int64Index([702570, 702571], dtype='int64'),
#  'en_vide': Int64Index([681926], dtype='int64'),
#  'en_blankets': Int64Index([77047, 77048, 77049, 77050, 77051, 77052, 77054], dtype='int64'),
#  'en_curarize': Int64Index([160428, 160429], dtype='int64'),
#  'en_pump': Int64Index([511787, 511788, 511789, 511790, 511791, 511792, 511793, 511794,
#              511795, 511796, 511803, 511805, 511829, 511831, 511834, 511836,
#              511837, 511840],
#             dtype='int64'),
#  'en_congress_of_troppau': Int64Index([142886], dtype='int64'),
#  'en_cointreau': Int64Index([130966], dtype='int64'),
#  'en_peter_henry_emerson': Int64Index([477853], dtype='int64'),
#  'en_puma': Int64Index([511741, 511742, 511743, 511744, 511745, 511746, 511747, 511748,
#              511749, 511750, 511751, 511752, 511753, 511755],
#             dtype='int64'),
#  'en_majority': Int64Index([391367, 391371, 391372, 391373, 391374, 391377], dtype='int64'),
#  'en_achille_emana': Int64Index([6157], dtype='int64'),
#  'en_mikhail_youzhny': Int64Index([411921], dtype='int64'),
#  'en_pumi': Int64Index([511766], dtype='int64'),
#  'en_igor_mitoraj': Int64Index([317098], dtype='int64'),
# ...
#  'en_islands_of_tuvalu': Int64Index([339938], dtype='int64'),
#  'en_trypanosomes': Int64Index([659614, 659615], dtype='int64'),
#  'en_soiree': Int64Index([591190, 591191], dtype='int64'),
#  'en_cross_oneself': Int64Index([157637, 157638, 157639, 157640], dtype='int64'),
#  'en_lower_hunter_national_park': Int64Index([385247], dtype='int64'),
#  'en_bibtex': Int64Index([72219], dtype='int64'),
#  'en_fund_of_the_united_nations_environment_programme': Int64Index([258992], dtype='int64'),
#  'en_o.k.': Int64Index([449040, 449076, 449082, 449084, 449098, 449135, 449137, 449152,
#              449154, 449160],
#             dtype='int64'),
#  'en_family_lobotidae': Int64Index([231820, 231821], dtype='int64'),
#  'en_chris_sawyer\xe2\x80\x99s_locomotion': Int64Index([121194], dtype='int64'),
#  'en_synodontis_notatus': Int64Index([625645], dtype='int64'),
#  'en_passport_data': Int64Index([468790], dtype='int64'),
#  'en_code_for_the_implementation_of_mandatory_international_maritime_organization_instruments': Int64Index([130041], dtype='int64'),
#  'en_be_on_account_of': Int64Index([69776], dtype='int64'),
#  'en_kiaugh': Int64Index([356626, 356627, 356628], dtype='int64'),
#  'en_popular_favour': Int64Index([493847], dtype='int64'),
#  'en_inconsequential': Int64Index([321907, 321908], dtype='int64'),
#  'en_drill_core': Int64Index([194703], dtype='int64'),
#  'en_take_someone_for': Int64Index([628108], dtype='int64'),
#  'en_congentital': Int64Index([142548, 142549], dtype='int64'),
#  'en_seasonal_workers': Int64Index([562871, 562872], dtype='int64'),
#  'en_house_of_alba': Int64Index([310286], dtype='int64'),
#  'en_vbulletin': Int64Index([678603], dtype='int64'),
#  'en_grundrisse': Int64Index([287434], dtype='int64'),
#  'en_methanosarcina': Int64Index([408914], dtype='int64'),
#  'en_podocarpus_national_park': Int64Index([489973], dtype='int64'),
#  'en_valery_larbaud': Int64Index([676879], dtype='int64'),
#  'en_athabaskan_languages': Int64Index([48573], dtype='int64'),
#  'en_suns': Int64Index([619791, 619802], dtype='int64'),
#  'en_international_conference_on_the_organization_of_research_and_training_in_africa_in_relation_to_the_study,_conservation_and_utilization_of_natural_resources': Int64Index([332843], dtype='int64'),
#  'en_proteracanthus_sarissophorus': Int64Index([507554], dtype='int64'),
#  'en_fusarium_solani': Int64Index([260101, 260102, 260103, 260104], dtype='int64'),
#  'en_epiderm': Int64Index([214769, 214770], dtype='int64'),
#  'en_self-rule': Int64Index([567415], dtype='int64'),
#  'en_sergey_gorshkov': Int64Index([570138], dtype='int64'),
#  'en_shrink_from': Int64Index([577921], dtype='int64'),
#  'en_stonecrop_family': Int64Index([610773, 610774, 610775], dtype='int64'),
#  'en_enter_phone_uri': Int64Index([213023], dtype='int64'),
#  'en_julien_fourni\xc3\xa9': Int64Index([352183], dtype='int64'),
#  'en_wilbur_wright': Int64Index([697215, 697216], dtype='int64'),
#  'en_plotosus_canius': Int64Index([488937], dtype='int64'),
#  'en_bobwhite_quail': Int64Index([80336], dtype='int64'),
#  'en_suspiciously': Int64Index([622357], dtype='int64'),
#  'en_workshop_on_international_law_and_nationality_laws_in_the_former_ussr': Int64Index([703570], dtype='int64'),
#  'en_balletic': Int64Index([57693], dtype='int64'),
#  'en_open_trade': Int64Index([452396, 452397], dtype='int64'),
#  'en_ulyanovsk_oblast': Int64Index([664058], dtype='int64'),
#  'en_rejang': Int64Index([529792], dtype='int64'),
#  'en_osteoglossum_bicirrhosum': Int64Index([457301], dtype='int64'),
#  'en_communication_services_unit': Int64Index([137308], dtype='int64'),
#  'en_head_of_the_political_department': Int64Index([296978], dtype='int64'),
#  'en_christopher_uckermann': Int64Index([121574], dtype='int64'),
#  'en_egyptian_goose': Int64Index([204350, 204351, 204352, 204353, 204354, 204355], dtype='int64'),
#  'en_adam\xe2\x80\x99s_apple': Int64Index([8365, 8366, 8367, 8368, 8369, 8370, 8371, 8372, 8373], dtype='int64'),
#  'en_second_literacy': Int64Index([563639], dtype='int64'),
#  'en_organized_noize': Int64Index([455616], dtype='int64'),
#  'en_nitrite_reductase': Int64Index([438034], dtype='int64'),
#  'en_taag_angola_airlines': Int64Index([626213], dtype='int64'),
#  'en_ana_ivanovi\xc4\x87': Int64Index([28240], dtype='int64'),
#  'en_isidoro_gallo': Int64Index([339706], dtype='int64'),
#  'en_mutual_assured_destruction': Int64Index([426696], dtype='int64'),
#  'en_corynebacterium_equi': Int64Index([150919, 150920], dtype='int64'),
#  'en_humanity:_hour_i': Int64Index([311829], dtype='int64'),
#  'en_bush_wife': Int64Index([94675], dtype='int64'),
#  'en_kalkar': Int64Index([353678], dtype='int64'),
#  'en_aplocheilus_dayi': Int64Index([35803], dtype='int64'),
#  'en_g\xc3\xa9rard_causs\xc3\xa9': Int64Index([269943], dtype='int64'),
#  'en_phalacrosis': Int64Index([478655], dtype='int64'),
#  'en_hebrides_overture': Int64Index([298559], dtype='int64'),
#  'en_manyema': Int64Index([395886], dtype='int64'),
#  'en_jon_juaristi': Int64Index([349484], dtype='int64'),
#  'en_straitlaced': Int64Index([612128, 612130, 612131, 612133], dtype='int64'),
#  'en_wheatstone_bridge_salinometer': Int64Index([694363], dtype='int64'),
#  'en_recovery_and_rehabilitation_programme': Int64Index([524877], dtype='int64'),
#  'en_nuclear_reaction': Int64Index([443228], dtype='int64'),
#  'en_above-knee_amputation': Int64Index([2423], dtype='int64'),
#  'en_tulu\xc3\xa1': Int64Index([660286], dtype='int64'),
#  'en_eastern_african_action_plan': Int64Index([199973, 199974], dtype='int64'),
#  'en_non-self-governing_territory': Int64Index([439905], dtype='int64'),
#  'en_regional_high_level_ad_hoc_committee': Int64Index([528283], dtype='int64'),
#  'en_pea_mosaic_virus': Int64Index([471780, 471781, 471782, 471783], dtype='int64'),
#  'en_quisling': Int64Index([516963, 516964, 516967, 516968], dtype='int64'),
#  'en_leptotene': Int64Index([372331], dtype='int64'),
#  'en_orange_amanita': Int64Index([453966, 453967, 453968, 453969, 453970, 453971, 453972, 453973,
#              453974, 453975, 453976],
#             dtype='int64'),
#  'en_bird_nests': Int64Index([74733], dtype='int64'),
#  'en_basel_dove': Int64Index([61183], dtype='int64'),
#  'en_julia_ormond': Int64Index([352150], dtype='int64'),
#  'en_belgrade_international_workshop': Int64Index([67968], dtype='int64'),
#  'en_juan_morel_campos': Int64Index([351360], dtype='int64'),
#  'en_funnel_weaver': Int64Index([259296, 259297], dtype='int64'),
#  'en_gallegos_de_arga\xc3\xb1\xc3\xa1n': Int64Index([261523], dtype='int64'),
#  'en_upholder': Int64Index([673457, 673458, 673459, 673460, 673461, 673462], dtype='int64'),
#  'en_john_akii-bua': Int64Index([347345], dtype='int64'),
#  'en_consumer_survey': Int64Index([145012], dtype='int64'),
#  'en_aermacchi_mb-326': Int64Index([12617], dtype='int64'),
#  'en_birgir_sigur\xc3\xb0sson': Int64Index([74818], dtype='int64'),
#  'en_what_ever_happened_to_baby_jane?': Int64Index([694231], dtype='int64'),
#  'en_international_federation_of_automatic_control': Int64Index([333457], dtype='int64'),
#  'en_the_men_who_tread_on_the_tiger\xe2\x80\x99s_tail': Int64Index([638943], dtype='int64'),
#  'en_bendwise': Int64Index([69016], dtype='int64'),
#  'en_seminar_on_the_utilization_of_satellite_data_with_special_regard_to_tropical_cyclone_warnings': Int64Index([568159], dtype='int64'),
#  'en_bridelia': Int64Index([88165], dtype='int64'),
#  'en_working_group_on_agricultural_statistics': Int64Index([702774, 702775], dtype='int64'),
#  'en_body_type': Int64Index([80664, 80665], dtype='int64'),
#  'en_meconic_acid': Int64Index([403799], dtype='int64'),
#  'en_hrungnir': Int64Index([310866], dtype='int64'),
#  'en_disparate': Int64Index([186307, 186308, 186309, 186310], dtype='int64'),
#  'en_william_primrose': Int64Index([698213], dtype='int64'),
#  'en_project_constellation': Int64Index([505336], dtype='int64'),
#  'en_forests': Int64Index([250351, 250357, 250358, 250359, 250366], dtype='int64'),
#  'en_mikoyan-gurevich_mig-19': Int64Index([411953], dtype='int64'),
#  'en_neoplasm_antigens': Int64Index([433591, 433592, 433593, 433594, 433595, 433596], dtype='int64'),
#  'en_steering_column': Int64Index([607592], dtype='int64'),
#  'en_mikoyan-gurevich_mig-15': Int64Index([411951], dtype='int64'),
#  'en_mental_imagery': Int64Index([406999, 407000], dtype='int64'),
#  'en_martell_webster': Int64Index([399200], dtype='int64'),
#  'en_alberto_enr\xc3\xadquez_gallo': Int64Index([19578], dtype='int64'),
#  'en_francis_peyton_rous': Int64Index([253572, 253573], dtype='int64'),
#  'en_chuck_berry': Int64Index([121992], dtype='int64'),
#  'en_gerrhonotus': Int64Index([270403, 270404], dtype='int64'),
#  'en_paecilomyces_fumosoroseus': Int64Index([462171], dtype='int64'),
#  'en_kalinowski\xe2\x80\x99s_mouse_opossum': Int64Index([353669], dtype='int64'),
#  'en_international_longevity_centre': Int64Index([333887], dtype='int64'),
#  'en_international_solar-terrestial_physics_program': Int64Index([334655], dtype='int64'),
#  'en_double-faced': Int64Index([192162, 192163, 192164, 192165], dtype='int64'),
#  'en_trading_profits': Int64Index([652137, 652138, 652139], dtype='int64'),
#  'en_corticoids': Int64Index([150802, 150803], dtype='int64'),
#  'en_genus_chaenomeles': Int64Index([266601, 266602], dtype='int64'),
#  'en_jaroszewice': Int64Index([343891], dtype='int64'),
#  'en_central_governorate': Int64Index([111082], dtype='int64'),
#  'en_travel_around': Int64Index([654604], dtype='int64'),
#  'en_bog_soils': Int64Index([80839], dtype='int64'),
#  'en_endemicity': Int64Index([210412], dtype='int64'),
#  'en_foliation': Int64Index([247738, 247739], dtype='int64'),
#  'en_cliche': Int64Index([126382, 126383, 126385, 126388, 126389, 126390, 126391, 126392,
#              126397, 126399],
#             dtype='int64'),
#  'en_tirana_international_airport_n\xc3\xabn\xc3\xab_tereza': Int64Index([646498], dtype='int64'),
#  'en_folding_trapdoor_spider': Int64Index([247693], dtype='int64'),
#  'en_dragon_ball_z:_wrath_of_the_dragon': Int64Index([193301], dtype='int64'),
#  'en_the_seven_habits_of_highly_effective_people': Int64Index([640418], dtype='int64'),
#  'en_field_mouse': Int64Index([238792, 238793, 238794, 238795, 238796], dtype='int64'),
#  'en_capsicum_annuum_grossum': Int64Index([102473], dtype='int64'),
#  'en_clichy': Int64Index([126400], dtype='int64'),
#  'en_ach\xc3\xa9': Int64Index([6000], dtype='int64'),
#  'en_other_people\xe2\x80\x99s_property': Int64Index([457559, 457560], dtype='int64'),
#  'en_capros_aper': Int64Index([102456], dtype='int64'),
#  'en_satanism': Int64Index([556095], dtype='int64'),
#  'en_plant_hormone': Int64Index([486976], dtype='int64'),
#  'en_default_host': Int64Index([171043], dtype='int64'),
#  'en_catechol': Int64Index([108236], dtype='int64'),
#  'en_declaration_of_santiago_on_confidence-_and_security-building_measures': Int64Index([169669], dtype='int64'),
#  'en_programmes_industry': Int64Index([505078], dtype='int64'),
#  'en_family_laricariidae': Int64Index([231777, 231778], dtype='int64'),
#  'en_mind-numbing': Int64Index([413245, 413246], dtype='int64'),
#  'en_hit_draw': Int64Index([305267, 305268], dtype='int64'),
#  'en_five-spot_burnet': Int64Index([243131], dtype='int64'),
#  'en_cruelty_and_the_beast': Int64Index([158306], dtype='int64'),
#  'en_azara\xe2\x80\x99s_grass_mouse': Int64Index([54436], dtype='int64'),
#  'en_pioneer_industry': Int64Index([484447, 484448], dtype='int64'),
#  'en_dennis_schulp': Int64Index([174420], dtype='int64'),
#  'en_sunshiny': Int64Index([619780, 619781, 619782, 619783], dtype='int64'),
#  'en_mahayana_buddhism': Int64Index([390550], dtype='int64'),
#  'en_biological_control_agent': Int64Index([74105, 74106], dtype='int64'),
#  'en_1530s': Int64Index([113], dtype='int64'),
#  'en_abbasid': Int64Index([907, 908, 909], dtype='int64'),
#  'en_estadio_latinoamericano': Int64Index([218189], dtype='int64'),
#  'en_aeropostal_alas_de_venezuela': Int64Index([12748], dtype='int64'),
#  'en_thrown': Int64Index([643519, 643520, 643524, 643525, 643526, 643527, 643528, 643529,
#              643531],
#             dtype='int64'),
#  'en_asian_subprogramme_on_biotechnology_and_biodiversity': Int64Index([45064], dtype='int64'),
#  'en_villaherreros': Int64Index([682749], dtype='int64'),
#  'en_office_of_foreign_disaster_assistance': Int64Index([447840], dtype='int64'),
#  'en_organisation_of_research': Int64Index([455416], dtype='int64'),
#  'en_front_side': Int64Index([256987], dtype='int64'),
#  'en_frozen_products': Int64Index([257131, 257132], dtype='int64'),
#  'en_guan_hanqing': Int64Index([287762], dtype='int64'),
#  'en_asian_organization_of_supreme_audit_institutions': Int64Index([44986], dtype='int64'),
#  'en_burseraceae': Int64Index([94432, 94433], dtype='int64'),
#  'en_primping': Int64Index([501719], dtype='int64'),
#  'en_abkhazia': Int64Index([1838], dtype='int64'),
#  'en_hagakure': Int64Index([291106], dtype='int64'),
#  'en_basardilla': Int64Index([61071], dtype='int64'),
#  'en_unsuspecting': Int64Index([672532, 672533, 672534, 672535, 672536, 672537, 672538, 672539,
#              672540, 672541, 672543],
#             dtype='int64'),
#  'en_uesugi_kagekatsu': Int64Index([663470], dtype='int64'),
#  'en_standardized_monitoring_and_assessment_of_relief_and_transitions': Int64Index([604544], dtype='int64'),
#  'en_forty_winks': Int64Index([251765, 251766, 251767, 251768, 251769, 251770], dtype='int64'),
#  'en_bitmap': Int64Index([75266, 75267, 75269, 75270, 75271, 75272], dtype='int64'),
#  'en_huatabampo': Int64Index([310984], dtype='int64'),
#  'en_anthony_trollope': Int64Index([33160], dtype='int64'),
#  'en_keith_mitchell': Int64Index([355564], dtype='int64'),
#  'en_biogeocenosis': Int64Index([74013], dtype='int64'),
#  'en_raphael_sch\xc3\xa4fer': Int64Index([520719], dtype='int64'),
#  'en_nasal_catarrh': Int64Index([429503], dtype='int64'),
#  'en_power_rangers': Int64Index([497181], dtype='int64'),
#  'en_ricardo_bellver': Int64Index([538742], dtype='int64'),
#  'en_vague': Int64Index([676489, 676490, 676491, 676493, 676494, 676495, 676496, 676497,
#              676502, 676503],
#             dtype='int64'),
#  'en_precocious_germination': Int64Index([498334], dtype='int64'),
#  'en_baker_street': Int64Index([57048], dtype='int64'),
#  'en_training_seminar_on_the_prevention_and_correction_of_juvenile_delinquency_in_the_context_of_development': Int64Index([652627], dtype='int64'),
#  'en_computer_menu': Int64Index([139741, 139742], dtype='int64'),
#  'en_renter': Int64Index([531957, 531958, 531960, 531961], dtype='int64'),
#  'en_dungeon_east': Int64Index([197532], dtype='int64'),
#  'en_convention_for_the_creation_of_an_international_criminal_court': Int64Index([147128], dtype='int64'),
#  'en_turbo_petholatus': Int64Index([660858], dtype='int64'),
#  'en_lamborghini_v10': Int64Index([363687], dtype='int64'),
#  'en_united_nations_survey_of_juvenile_crime_and_delinquency_and_the_treatment_of_juvenile_offenders,_1970_-_1985': Int64Index([669573], dtype='int64'),
#  'en_genus_scardinius': Int64Index([268314, 268315], dtype='int64'),
#  'en_lycengraulis_batesii': Int64Index([388014], dtype='int64'),
#  'en_sergi_l\xc3\xb3pez_i_ayats': Int64Index([570154], dtype='int64'),
#  'en_captain_hero': Int64Index([102572], dtype='int64'),
#  'en_arab_planning_institute': Int64Index([38520], dtype='int64'),
#  'en_statement_of_principles': Int64Index([606199], dtype='int64'),
#  'en_the_republic_of_chad': Int64Index([639855], dtype='int64'),
#  'en_southboy': Int64Index([595020], dtype='int64'),
#  'en_undp/sweden_trust_fund_to_support_the_rehabilitation_and_sustainable_development_of_war-torn_areas_in_croatia': Int64Index([666496], dtype='int64'),
#  'en_first_past_the_post': Int64Index([242225], dtype='int64'),
#  'en_rosy_boa': Int64Index([545549, 545550], dtype='int64'),
#  'en_doogie_howser': Int64Index([191406], dtype='int64'),
#  'en_g\xc3\xbcy\xc3\xbck_khan': Int64Index([290102], dtype='int64'),
#  'en_the_maxx': Int64Index([638911], dtype='int64'),
#  'en_cigarette_smoking_man': Int64Index([122580], dtype='int64'),
#  'en_cusco_region': Int64Index([161332], dtype='int64'),
#  'en_ssangyong_motor_company': Int64Index([603312], dtype='int64'),
#  'en_la_belle_ferroni\xc3\xa8re': Int64Index([361412], dtype='int64'),
#  'en_merenre_nemtyemsaf_ii': Int64Index([407516], dtype='int64'),
#  ...}

# %%
# Words we should totally try to translate

# en_pseudo-sophisticated
# en_peppermint_patty'
# en_freedom_of_mobile_multimedia_access
# en_love_wave
