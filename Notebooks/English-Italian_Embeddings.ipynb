# %% [markdown]
# # English - Italian Embeddings (3 versions)
# `w266 Final Project: Crosslingual Word Embeddings`
#
# Instead of traning on randomly substituted words, here we'll choose the translation that is closest to the context embedding vector.

# %% [markdown]
# # Notebook Setup

# %%
# general imports
from __future__ import print_function
import time
import pickle
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# tell matplotlib not to open a new window
# %matplotlib inline

# autoreload modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# __Base Paths__

# %%
BASE = '/home/mmillervedam/Data'
PROJ = '/home/mmillervedam/ProjectRepo'
GTT_BASE = PROJ + '/BaselineModels/data/ground_truth_translations/'
#PROJ = '/Users/mona/OneDrive/repos/final_proj/W266-Fall-2017-Final-Project'

# directory to save pickled embeddings
SAVE_TO = BASE + '/embeddings'

# %% [markdown]
# __Globals__ - _the parameters below fully determine all 3 models in this NB_

# %%
# Data
LANG = ('en','it')
FULL_TEXT = "/home/miwamoto/en_it_shuf.txt"
VOCAB_INDEX = BASE + '/vocab/en_it_small.pkl'
PANLEX = BASE + '/panlex/en_it_dict.pkl'
GTT_PATH = GTT_BASE + "%s-%s-clean.csv" % (LANG[0], LANG[1])

# Model
EMBEDDING_SIZE = 200

# Training
nBATCHES = 50000 # <<< 1 epoch with our 1 million sentence corpus
BATCH_SIZE = 48
WINDOW_SIZE = 4
MAX_EPOCHS = 5 # fail safe
ALPHA = 0.5 # authors use a much smaller learning rate but train longer

# %% [markdown]
# # Load Data

# %%
from parsing import Corpus, BilingualVocabulary, batch_generator, get_common_words

# %%
# load corpus
raw_data = Corpus(FULL_TEXT)

# %%
# load panlex dictionary
with open(PANLEX,'rb') as f:
    translations = pickle.load(f)

# %%
# load vocabulary
vocab = BilingualVocabulary([], languages = LANG)
with open(VOCAB_INDEX,'rb') as f:
    vocab.load_from_index(pickle.load(f))

# %%
# confirmations
print('... loaded %s panlex translations'%(len(translations)))
print('... loaded %s word %s vocabulary'%(vocab.size,vocab.language))
# Out:
# ... loaded 525091 panlex translations
# ... loaded 20003 word ('en', 'it') vocabulary

# %%
# Validation Words (for training printout)
TEST_WORDS = vocab.to_ids(['en_the','en_last', 'it_si', 'it_suo'])
print('... test word ids:', TEST_WORDS)
# Out:
# ... test word ids: [3, 239, 10020, 10040]

# %%
# Ground Truth Translations
GTT_DF = pd.read_csv(GTT_PATH, names = [LANG[0], LANG[1]], sep=' ', header=None)
print('... loaded %s ground truth translations.'%(len(GTT_DF)))
# Out:
# ... loaded 103613 ground truth translations.

# %%
a = get_common_words(vocab)

# %%
a
# Out:
# {'en_comics',
#  'en_basel',
#  'en_counterpart',
#  'it_migliora',
#  'en_things',
#  'en_attested',
#  'en_karnataka',
#  'it_migliore',
#  'en_expenses',
#  'it_ritmica',
#  'en_masterpiece',
#  'en_state',
#  'en_distortion',
#  'en_killers',
#  'it_platone',
#  'en_disk',
#  'it_lentamente',
#  'it_promettente',
#  'it_consolidare',
#  'en_bengali',
#  'en_interim',
#  'en_inevitable',
#  'en_examination',
#  'en_ethics',
#  'it_precisione',
#  'it_foto',
#  'en_extended',
#  'it_queen',
#  'en_southwest',
#  'it_sonata',
#  'en_wake',
#  'en_crash',
#  'en_transformation',
#  'en_exact',
#  'it_ginevra',
#  'it_sino',
#  'it_apre',
#  'en_get',
#  'en_oceans',
#  'en_gear',
#  'it_spartiacque',
#  'it_consumo',
#  'en_complex',
#  'it_vegetazione',
#  'it_limitare',
#  'it_cattura',
#  'en_storms',
#  'en_ran',
#  'en_czechoslovakia',
#  'en_saint',
#  'en_bmw',
#  'en_develop',
#  'en_timing',
#  'en_initiation',
#  'it_sorprendente',
#  'it_cuori',
#  'it_improvviso',
#  'en_bottom',
#  'it_improvvisa',
#  'en_mall',
#  'it_cuore',
#  'it_mostra',
#  'en_stefan',
#  'it_space',
#  'it_morente',
#  'en_beginnings',
#  'en_ram',
#  'it_rilevato',
#  'it_ribelle',
#  'it_gelosia',
#  'en_reversed',
#  'it_fifa',
#  'en_anime',
#  'en_spectrum',
#  'en_mickey',
#  'it_niente',
#  'en_encountered',
#  'it_volume',
#  'en_hitting',
#  'en_bermuda',
#  'en_divinity',
#  'en_uruguay',
#  'en_strip',
#  'en_protestant',
#  'en_attacks',
#  'en_author',
#  'it_qualifica',
#  'it_notato',
#  'en_hawks',
#  'en_resource',
#  'it_spera',
#  'en_newspaper',
#  'en_church',
#  'en_function',
#  'it_celtica',
#  'en_grandson',
#  'en_altitude',
#  'en_sinking',
#  'en_nobody',
#  'en_prospects',
#  'it_rissa',
#  'en_figures',
#  'it_iniezione',
#  'it_molla',
#  'en_licensing',
#  'en_explosives',
#  'it_vinile',
#  'it_molle',
#  'en_losses',
#  'en_bicycle',
#  'en_pirate',
#  'en_chemistry',
#  'en_ideals',
#  'en_planned',
#  'en_achilles',
#  'en_audition',
#  'it_gente',
#  'it_saraceni',
#  'en_magnitude',
#  'en_nonprofit',
#  'en_essential',
#  'it_abbreviato',
#  'it_terra',
#  'it_turismo',
#  'it_theta',
#  'it_terre',
#  'en_render',
#  'en_africa',
#  'it_carestia',
#  'it_olive',
#  'it_apple',
#  'it_oliva',
#  'en_fencing',
#  'it_fregata',
#  'it_notata',
#  'en_dock',
#  'en_aggressive',
#  'en_herzegovina',
#  'it_siluro',
#  'en_panthers',
#  'it_tram',
#  'it_cugino',
#  'it_soldato',
#  'en_ghana',
#  'it_efficiente',
#  'en_worst',
#  'it_soldati',
#  'en_bilateral',
#  'en_statesman',
#  'it_vangelo',
#  'en_strictly',
#  'en_investment',
#  'it_venezuela',
#  'en_worse',
#  'it_ravenna',
#  'en_globally',
#  'en_silk',
#  'it_raggiunto',
#  'en_commons',
#  'en_failed',
#  'it_papiro',
#  'en_theological',
#  'it_fretta',
#  'en_fulfill',
#  'en_australia',
#  'it_mente',
#  'it_vagamente',
#  'it_genesi',
#  'it_gaetano',
#  'it_diagramma',
#  'en_somalia',
#  'en_cyprus',
#  'it_jack',
#  'en_particle',
#  'en_fame',
#  'en_alley',
#  'it_pulizia',
#  'en_tour',
#  'en_bosnia',
#  'en_reporter',
#  'it_archeologia',
#  'it_ramo',
#  'en_signature',
#  'it_sentimento',
#  'it_innovazione',
#  'en_commitment',
#  'en_owen',
#  'it_affrontare',
#  'it_suzuki',
#  'it_ucraino',
#  'en_chest',
#  'en_pitch',
#  'it_pin',
#  'en_fortified',
#  'en_chess',
#  'en_mack',
#  'it_port',
#  'it_ucraina',
#  'en_turbine',
#  'en_bundle',
#  'it_forte',
#  'en_horizon',
#  'en_membrane',
#  'it_aspettare',
#  'en_game',
#  'it_bosco',
#  'en_injured',
#  'en_comfort',
#  'it_uganda',
#  'en_provision',
#  'it_incrociatore',
#  'it_acque',
#  'en_genius',
#  'it_disco',
#  'it_acqua',
#  'en_expensive',
#  'en_tom',
#  'it_cannes',
#  'en_ludwig',
#  'en_grassland',
#  'it_fascista',
#  'it_bonaparte',
#  'it_man',
#  'it_pericolosit\xc3\xa0',
#  'en_almost',
#  'it_fidanzata',
#  'en_respects',
#  'en_shift',
#  'it_disarmo',
#  'it_fidanzato',
#  'it_figure',
#  'en_mission',
#  'en_branded',
#  'en_conversation',
#  'en_irish',
#  'it_consegnato',
#  'en_setting',
#  'en_gravity',
#  'it_cadavere',
#  'en_waste',
#  'en_violence',
#  'it_emma',
#  'it_ferro',
#  'en_validity',
#  'it_uefa',
#  'en_dylan',
#  'it_ferri',
#  'it_insediamento',
#  'en_literal',
#  'en_leopard',
#  'en_night',
#  'en_taxes',
#  'en_itunes',
#  'en_portland',
#  'en_dinosaur',
#  'en_granted',
#  'it_peli',
#  'it_proiettile',
#  'en_importance',
#  'it_robin',
#  'en_memorial',
#  'en_scots',
#  'en_calendar',
#  'en_history',
#  'en_roy',
#  'en_shoot',
#  'en_velocity',
#  'en_baltic',
#  'en_october',
#  'en_rob',
#  'en_appreciated',
#  'en_rod',
#  'en_princeton',
#  'en_barrier',
#  'it_programmato',
#  'en_homer',
#  'en_ron',
#  'it_cadere',
#  'en_commission',
#  'en_waiting',
#  'en_rights',
#  'it_contea',
#  'it_autunno',
#  'en_other',
#  'it_sardegna',
#  'en_liverpool',
#  'it_verticale',
#  'en_mechanic',
#  'en_posthumous',
#  'it_ghetto',
#  'it_opera',
#  'en_dairy',
#  'it_concorrenza',
#  'it_adelaide',
#  'en_column',
#  'en_damages',
#  'it_tessile',
#  'en_captured',
#  'it_pieno',
#  'en_moderate',
#  'it_spezia',
#  'en_immigration',
#  'en_scarce',
#  'en_damaged',
#  'it_martello',
#  'en_install',
#  'it_dean',
#  'en_waterfall',
#  'en_surgery',
#  'en_tried',
#  'en_vision',
#  'it_misurare',
#  'it_polvere',
#  'en_noir',
#  'en_byzantine',
#  'it_primitiva',
#  'it_youtube',
#  'it_primitive',
#  'it_piuttosto',
#  'en_authenticity',
#  'en_maritime',
#  'it_tenuta',
#  'it_originario',
#  'it_sciolto',
#  'en_license',
#  'en_winner',
#  'en_numbering',
#  'it_australia',
#  'en_pirates',
#  'en_emerging',
#  'en_travels',
#  'en_thermal',
#  'en_slave',
#  'en_ballet',
#  'en_come',
#  'it_identit\xc3\xa0',
#  'en_coma',
#  'en_courage',
#  'en_brush',
#  'it_romanzo',
#  'en_vacant',
#  'en_melody',
#  'it_misterioso',
#  'en_base',
#  'en_family',
#  'en_faculty',
#  'en_satire',
#  'it_volare',
#  'en_limitations',
#  'en_bugs',
#  'it_legno',
#  'it_sessione',
#  'it_substrato',
#  'en_mozart',
#  'it_vocazione',
#  'en_bass',
#  'it_keith',
#  'en_spend',
#  'it_legna',
#  'it_consigli',
#  'en_literacy',
#  'en_ally',
#  'it_bergamo',
#  'it_biologia',
#  'it_virtuale',
#  'en_manchester',
#  'it_debutto',
#  'en_generations',
#  'it_manhattan',
#  'it_istituto',
#  'en_christopher',
#  'en_regulations',
#  'it_generano',
#  'en_violin',
#  'en_assistant',
#  'it_sorgenti',
#  'en_saddle',
#  'it_derivata',
#  'it_modella',
#  'it_modello',
#  'it_seriamente',
#  'en_patriot',
#  'it_editto',
#  'en_video',
#  'it_modelli',
#  'it_discreta',
#  'en_consistent',
#  'en_dedicated',
#  'en_booth',
#  'en_boundary',
#  'en_choice',
#  'en_supplied',
#  'en_factor',
#  'it_discreto',
#  'it_acquistato',
#  'en_badly',
#  'en_reason',
#  'it_evidente',
#  'it_eccezionale',
#  'it_png',
#  'en_cuba',
#  'it_proporre',
#  'en_abolished',
#  'en_destiny',
#  'it_sting',
#  'en_supplier',
#  'en_skeleton',
#  'it_cabaret',
#  'it_offensivo',
#  'en_entrepreneur',
#  'it_reportage',
#  'it_funghi',
#  'it_offensiva',
#  'en_divine',
#  'en_restriction',
#  'en_diving',
#  'en_career',
#  'en_identifying',
#  'en_commercial',
#  'en_while',
#  'it_fiction',
#  'it_racconto',
#  'en_torpedo',
#  'it_canone',
#  'en_pure',
#  'it_partito',
#  'it_racconta',
#  'it_diciannove',
#  'en_favored',
#  'it_cera',
#  'en_romans',
#  'en_tragedy',
#  'en_walls',
#  'en_bitter',
#  'en_problem',
#  'it_prete',
#  'en_sexuality',
#  'it_esaminare',
#  'it_adamo',
#  'it_accordo',
#  'en_guidelines',
#  'en_dividing',
#  'en_threatening',
#  'en_justin',
#  'en_during',
#  'en_survival',
#  'it_potassio',
#  'it_adams',
#  'it_fattura',
#  'en_cooper',
#  'en_defend',
#  'en_hide',
#  'en_infamous',
#  'it_neoclassico',
#  'it_pisa',
#  'it_finire',
#  'en_financial',
#  'en_windows',
#  'it_dirigenti',
#  'en_maiden',
#  'it_cittadella',
#  'en_macedonia',
#  'en_vernon',
#  'it_pensa',
#  'it_cura',
#  'en_average',
#  'it_vigore',
#  'en_everywhere',
#  'it_franklin',
#  'en_independence',
#  'en_karate',
#  'en_honest',
#  'en_casualties',
#  'it_associazione',
#  'it_genesis',
#  'en_rapper',
#  'en_protective',
#  'it_frutti',
#  'it_elaborato',
#  'it_associazioni',
#  'en_iphone',
#  'it_frutto',
#  'en_fcc',
#  'en_scale',
#  'it_salita',
#  'it_ritrovo',
#  'it_silla',
#  'en_vault',
#  'en_albania',
#  'en_energy',
#  'en_side',
#  'en_dubai',
#  'it_cattolica',
#  'en_congregation',
#  'en_maurice',
#  'en_affection',
#  'it_wolf',
#  'en_eleven',
#  'en_nation',
#  'en_meal',
#  'it_segreteria',
#  'it_annunciato',
#  'en_guns',
#  'it_serra',
#  'it_anfibi',
#  'en_those',
#  'en_researchers',
#  'en_spot',
#  'it_capolinea',
#  'en_write',
#  'it_tyler',
#  'en_rain',
#  'en_rail',
#  'it_fischer',
#  'en_baton',
#  'en_employment',
#  'it_regio',
#  'it_esplosivo',
#  'it_lega',
#  'en_females',
#  'en_memorable',
#  'en_hormone',
#  'it_danubio',
#  'en_atmospheric',
#  'it_regia',
#  'en_honored',
#  'en_buzz',
#  'it_spalle',
#  'it_don',
#  'en_roth',
#  'en_negro',
#  'en_dorothy',
#  'it_calice',
#  'en_philosopher',
#  'it_asti',
#  'en_exceptionally',
#  'it_atena',
#  'en_earnings',
#  'it_frasi',
#  'it_contratti',
#  'en_freed',
#  'it_suicida',
#  'en_iowa',
#  'en_shrub',
#  'it_dos',
#  'en_renovation',
#  'en_unchanged',
#  'it_triassico',
#  'en_insane',
#  'it_savona',
#  'en_paternal',
#  'en_healing',
#  'en_trevor',
#  'it_anale',
#  'it_cina',
#  'en_engineering',
#  'it_costi',
#  'it_guardare',
#  'en_fog',
#  'en_energetic',
#  'it_master',
#  'it_osservatori',
#  'it_veneti',
#  'it_veneto',
#  'en_fox',
#  'en_rift',
#  'en_essay',
#  'en_wet',
#  'it_stabile',
#  'it_propriet\xc3\xa0',
#  'en_suffolk',
#  'en_for',
#  'en_defence',
#  'en_islam',
#  'it_lezione',
#  'en_parasite',
#  'en_activity',
#  'it_opzione',
#  'en_toronto',
#  'en_judgment',
#  'it_journal',
#  'en_experts',
#  'en_brass',
#  'en_primary',
#  'en_start',
#  'it_clan',
#  'en_pittsburgh',
#  'en_christmas',
#  'it_dotazione',
#  'en_stars',
#  'en_government',
#  'en_thousands',
#  'en_yeast',
#  'en_repeat',
#  'it_denti',
#  'en_stole',
#  'it_clay',
#  'it_settimanale',
#  'en_abortion',
#  'it_video',
#  'it_lubiana',
#  'en_historian',
#  'it_dente',
#  'en_stark',
#  'en_alpine',
#  'en_sciences',
#  'en_consist',
#  'it_justice',
#  'en_miner',
#  'it_rettangolare',
#  'en_definition',
#  'it_saccheggio',
#  'en_paddy',
#  'en_movie',
#  'it_cattolicesimo',
#  'en_provisional',
#  'en_develops',
#  'it_larve',
#  'en_plasma',
#  'it_crociata',
#  'en_monarch',
#  'en_compose',
#  'en_ajax',
#  'en_suit',
#  'en_strengthen',
#  'en_resulting',
#  'en_actions',
#  'en_vertical',
#  'en_physicians',
#  'en_alternative',
#  'en_daniel',
#  'it_endemico',
#  'it_televisione',
#  'en_oversee',
#  'en_evening',
#  'it_supergigante',
#  'en_rpg',
#  'it_conoscenze',
#  'en_hail',
#  'it_conoscenza',
#  'en_rpm',
#  'en_voivodeship',
#  'en_deliver',
#  'it_tratto',
#  'en_exodus',
#  'it_cilindrico',
#  'it_laureata',
#  'en_hair',
#  'it_laureato',
#  'it_concordia',
#  'it_glaciale',
#  'en_umbrella',
#  'en_brewery',
#  'en_apparatus',
#  'en_grave',
#  'it_stringa',
#  'it_recentemente',
#  'en_valencia',
#  'en_elimination',
#  'en_comic',
#  'it_cerca',
#  'it_allenamento',
#  'en_pilgrims',
#  'en_hiding',
#  'en_trapped',
#  'en_footballer',
#  'it_maxwell',
#  'en_marsh',
#  'it_niger',
#  'it_molly',
#  'it_nomadi',
#  'en_moist',
#  'en_voluntary',
#  'it_propulsore',
#  'it_luca',
#  'it_luce',
#  'it_houten',
#  'it_luci',
#  'en_relevant',
#  'it_amichevole',
#  'it_controversia',
#  'en_commander',
#  'it_heidelberg',
#  'en_grange',
#  'it_ryu',
#  'en_wanted',
#  'it_aliena',
#  'en_volcano',
#  'it_sorriso',
#  'it_onde',
#  'en_feud',
#  'it_profilo',
#  'it_profili',
#  'it_beatrice',
#  'it_norvegia',
#  'en_pleased',
#  'en_permits',
#  'en_awareness',
#  'en_underworld',
#  'it_anniversario',
#  'it_diciassette',
#  'it_scarto',
#  'it_eugene',
#  'it_pil',
#  'it_auschwitz',
#  'it_membrane',
#  'en_radial',
#  'en_denis',
#  'it_bersaglio',
#  'en_aaron',
#  'it_settentrionale',
#  'it_disciplina',
#  'it_contenere',
#  'en_lung',
#  'it_discipline',
#  'en_number',
#  'it_rifugio',
#  'it_arena',
#  'it_klaus',
#  'it_seguaci',
#  'it_proclama',
#  'it_provino',
#  'it_seguace',
#  'en_arabian',
#  'en_spiritual',
#  'en_password',
#  'en_hazard',
#  'it_pubblicare',
#  'it_cugina',
#  'it_nave',
#  'it_suo',
#  'it_persino',
#  'it_irlandese',
#  'it_sub',
#  'it_denuncia',
#  'it_sue',
#  'en_patch',
#  'en_extinction',
#  'en_duck',
#  'it_telecamera',
#  'en_rooms',
#  'en_sigma',
#  'en_overview',
#  'en_phone',
#  'it_sur',
#  'it_massimiliano',
#  'en_has',
#  'en_draft',
#  'en_medicinal',
#  'en_pitcher',
#  'en_sahara',
#  'en_luther',
#  'en_married',
#  'en_hat',
#  'en_spokesman',
#  'it_stemma',
#  'it_fata',
#  'en_speedway',
#  'it_infiorescenza',
#  'it_radiazioni',
#  'it_piccardia',
#  'it_vincere',
#  'en_lesson',
#  'it_schiavit\xc3\xb9',
#  'it_biologici',
#  'en_mid',
#  'en_containers',
#  'en_heated',
#  'it_meglio',
#  'en_drink',
#  'it_biologica',
#  'it_psi',
#  'it_aggiornamento',
#  'it_scena',
#  'en_statistics',
#  'it_siria',
#  'en_mir',
#  'it_determinante',
#  'en_mix',
#  'it_viola',
#  'en_brand',
#  'en_marvel',
#  'it_agricoltura',
#  'en_equilibrium',
#  'en_macau',
#  'en_norwegian',
#  'it_amelia',
#  'en_trigger',
#  'it_plurale',
#  'en_influenced',
#  'en_neutron',
#  'en_flexible',
#  'it_passione',
#  'it_rispettivamente',
#  'en_ears',
#  'en_league',
#  'en_besieged',
#  'it_granata',
#  'en_lists',
#  'it_preesistente',
#  'en_fowler',
#  'it_human',
#  'it_spiegazione',
#  'en_bacterial',
#  'it_pipistrello',
#  'en_churches',
#  'it_pena',
#  'en_consensus',
#  'en_had',
#  'it_gravit\xc3\xa0',
#  'en_nashville',
#  'en_motto',
#  'en_mecca',
#  'it_moda',
#  'en_synagogue',
#  'en_freedom',
#  'it_piombino',
#  'en_passenger',
#  'it_fonetica',
#  'en_around',
#  'it_coinvolto',
#  'en_licenses',
#  'en_giant',
#  'en_murray',
#  'it_divertimento',
#  'it_api',
#  'it_scherma',
#  'en_costume',
#  'en_calcium',
#  'en_experimental',
#  'en_removed',
#  'en_legislative',
#  'en_invade',
#  'it_schermo',
#  'it_maometto',
#  'it_bristol',
#  'en_scattering',
#  'en_magician',
#  'en_seeds',
#  'en_honours',
#  'en_perfectly',
#  'it_colpevole',
#  'it_inventore',
#  'en_static',
#  'en_calgary',
#  'en_officers',
#  'en_warwick',
#  'en_vii',
#  'en_marker',
#  'it_michelle',
#  'en_market',
#  'en_defeats',
#  'en_weakened',
#  'en_vic',
#  'it_ashley',
#  'en_via',
#  'en_london',
#  'en_manga',
#  'en_grip',
#  'it_indipendentemente',
#  'it_strutture',
#  'en_declared',
#  'it_struttura',
#  'it_pallavolo',
#  'en_grid',
#  'en_pipe',
#  'it_croato',
#  'en_switching',
#  'en_cowboys',
#  'it_mons',
#  'it_dritto',
#  'it_piumaggio',
#  'en_noon',
#  'en_acre',
#  'en_colorful',
#  'en_neat',
#  'it_poliziotto',
#  'en_near',
#  'it_contenente',
#  'en_urdu',
#  'it_canti',
#  'it_caterina',
#  'en_participants',
#  'en_mann',
#  'it_canto',
#  'en_vincent',
#  'it_misurata',
#  'it_ribalta',
#  'it_aquile',
#  'it_parziale',
#  'en_stopped',
#  'en_fight',
#  'it_franco',
#  'en_obtain',
#  'en_weapons',
#  'it_touch',
#  'en_saved',
#  'en_proclamation',
#  'en_dvd',
#  'it_fortemente',
#  'en_seriously',
#  'it_salerno',
#  'en_pomerania',
#  'it_amare',
#  'en_google',
#  'en_reflect',
#  'en_gentle',
#  'en_could',
#  'it_bibliotecario',
#  'en_medication',
#  'en_xavier',
#  'en_slate',
#  'it_beck',
#  'it_reno',
#  'it_willie',
#  'en_piece',
#  'en_separately',
#  'en_appointed',
#  'en_coke',
#  'en_legitimate',
#  'en_drama',
#  'it_collaboratore',
#  'en_slovenian',
#  'en_volunteer',
#  'it_prossimit\xc3\xa0',
#  'en_withdrawn',
#  'it_cantone',
#  'en_pray',
#  'en_distinguish',
#  'en_spell',
#  'it_bartolomeo',
#  'en_people',
#  'en_pozna\xc5\x84',
#  'en_albert',
#  'en_bowl',
#  'en_nelson',
#  'en_gill',
#  'it_lord',
#  'en_accelerated',
#  'en_toledo',
#  'en_george',
#  'it_sottofamiglia',
#  'en_colleague',
#  'en_millionaire',
#  'en_blamed',
#  'en_springs',
#  'en_reporting',
#  'en_hello',
#  'en_expansion',
#  'it_pok\xc3\xa9mon',
#  'en_apartment',
#  'it_voivodato',
#  'en_mind',
#  'en_formulation',
#  'it_mulini',
#  'en_finale',
#  'it_specialit\xc3\xa0',
#  'en_plaque',
#  'en_spirit',
#  'en_pointing',
#  'it_licenza',
#  'it_sigillo',
#  'it_licenze',
#  'en_fire',
#  'it_polacchi',
#  'en_exile',
#  'it_accusato',
#  'it_vestiti',
#  'en_dismissed',
#  'it_curioso',
#  'en_sauce',
#  'it_perdono',
#  'it_accusata',
#  'it_apparizione',
#  'it_dawn',
#  'en_marines',
#  'en_though',
#  'it_ordini',
#  'en_organ',
#  'it_afghanistan',
#  'en_chapel',
#  'en_mtv',
#  'en_plate',
#  'it_precedentemente',
#  'en_judo',
#  'en_troubled',
#  'it_rocca',
#  'en_ukrainian',
#  'en_jones',
#  'it_calvo',
#  'en_hollow',
#  'en_enthusiastic',
#  'it_area',
#  'en_front',
#  'it_attribuire',
#  'en_united',
#  'it_evolutiva',
#  'it_sentito',
#  'en_coliseum',
#  'it_nantes',
#  ...}

# %%
# Evaluation Words (for reporting recall)
eval_words = [w for w in get_common_words(vocab) if w.startswith(LANG[1])]
EVAL_IDS = vocab.to_ids(eval_words)
print('... loaded %s evaluation words.' % (len(EVAL_IDS)))
# Out:
# ... loaded 8516 evaluation words.

# %% [markdown]
# # Method 1: Random Translations

# %% [markdown]
# ### Initialize the model

# %%
from models import BiW2V_random

# create model
model_1 = BiW2V_random(bilingual_dict = translations,
                       vocab = vocab, H = EMBEDDING_SIZE)

# intialize TF graphs
model_1.BuildCoreGraph()
model_1.BuildTrainingGraph()
model_1.BuildValidationGraph()
# Out:
# ... TF graph created for BiW2V model.
# ... TF graph created for BiW2V training.
# ... TF graph created for BiW2V validation.

# %% [markdown]
# ### Training

# %%
# fresh data generator
DATA_GENERATOR = batch_generator(raw_data, vocab, BATCH_SIZE, WINDOW_SIZE, MAX_EPOCHS)

# %%
# train
start = time.time()
model_1.train(nBATCHES, DATA_GENERATOR, TEST_WORDS, learning_rate = ALPHA)
tot = (time.time() - start)
print('... {} batches trained in {} seconds'.format(nBATCHES, tot))
# Out:
# ... Model Initialized
# 	 <tf.Variable 'Embedding_Layer/ContextEmbeddings:0' shape=(20003, 200) dtype=float32_ref>
# 	 <tf.Variable 'Hidden_Layer/WordEmbeddings:0' shape=(20003, 200) dtype=float32_ref>
# 	 <tf.Variable 'Hidden_Layer/b:0' shape=(20003,) dtype=float32_ref>
# ... Starting Training
# ... STEP 0 : Average Loss : 0.000264484786987
#    [en_the] closest:  it_cristina, en_commented, it_sacerdotale, it_amiga, it_vantaggio, en_muhammad, it_gemello, it_esistente,
#    [en_last] closest:  en_n, en_ridge, it_kg, it_cancellare, it_professionistico, en_quad, it_consentire, it_arti,
#    [it_si] closest:  it_compiti, it_limitazione, en_sculptor, en_switching, en_solidarity, en_hereford, it_u, it_pesante,
#    [it_suo] closest:  it_abitanti, it_presentarsi, en_convert, en_regulate, it_notazione, en_son-in-law, it_compresa, it_girone,
# ... STEP 50000 : Average Loss : 4.10927392767
# ... STEP 100000 : Average Loss : 3.85516811703
#    [en_the] closest:  en_a, en_its, en_an, en_one, en_his, it_la, it_riunirsi, it_della,
#    [en_last] closest:  en_quad, it_consentire, en_n, it_salone, it_arti, it_professionistico, en_ridge, en_she,
#    [it_si] closest:  it_delle, it_settanta, en_acclaim, it_gli, it_ripetutamente, it_visconti, en_ion, it_materia,
#    [it_suo] closest:  it_abitanti, it_del, it_il, en_convert, en_be, it_rito, it_presentarsi, en_landscape,
# ... STEP 150000 : Average Loss : 3.77276867841
# ... STEP 200000 : Average Loss : 3.71266719249
#    [en_the] closest:  en_a, en_its, en_an, en_his, en_their, en_this, en_one, it_della,
#    [en_last] closest:  en_league, en_quad, en_after, it_professionistico, en_economist, it_arti, it_consentire, it_cancellare,
#    [it_si] closest:  it_delle, it_ripetutamente, it_visconti, it_settanta, it_le, it_gli, it_reliquia, en_acclaim,
#    [it_suo] closest:  it_un, it_il, it_del, it_abitanti, it_rito, en_convert, it_fu, en_landscape,
# ... STEP 250000 : Average Loss : 3.66867491206
# ... STEP 300000 : Average Loss : 3.62933794949
#    [en_the] closest:  en_its, en_a, en_an, en_this, en_their, en_his, en_one, it_della,
#    [en_last] closest:  en_after, en_league, en_final, en_before, en_until, en_first, en_quad, en_weeks,
#    [it_si] closest:  it_delle, it_ripetutamente, it_visconti, it_le, it_reliquia, en_hereford, en_ion, it_settanta,
#    [it_suo] closest:  en_his, it_un, it_rito, it_il, en_her, en_convert, it_del, it_abitanti,
# ... STEP 350000 : Average Loss : 3.60212432476
# ... STEP 400000 : Average Loss : 3.59838218079
#    [en_the] closest:  en_its, en_a, en_this, en_an, en_their, en_his, en_one, it_amiga,
#    [en_last] closest:  en_after, en_league, en_final, en_first, en_before, en_until, en_weeks, en_next,
#    [it_si] closest:  it_ripetutamente, it_le, it_visconti, it_delle, it_reliquia, en_hereford, it_dante, it_sulla,
#    [it_suo] closest:  en_his, en_her, it_un, it_questo, it_rito, it_proprio, it_momento, en_marketing,
# ... STEP 450000 : Average Loss : 3.56207469346
# ... STEP 500000 : Average Loss : 3.5358864178
#    [en_the] closest:  en_its, en_this, en_a, en_an, en_their, en_his, en_one, en_each,
#    [en_last] closest:  en_after, en_final, en_first, en_league, en_before, en_next, en_until, en_third,
#    [it_si] closest:  it_ripetutamente, it_le, it_visconti, it_delle, it_compiti, it_sulla, it_indirizzo, it_dante,
#    [it_suo] closest:  en_his, en_her, it_un, it_proprio, it_quale, it_questo, it_loro, it_rito,
# ... Training Complete
# ... 500000 batches trained in 1346.75051999 seconds

# %% [markdown]
# ### Save the Embeddings.

# %%
# context 
filename = SAVE_TO + '/en_it_rand_500K_V_dec19.pkl'
with open(filename, 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(model_1.context_embeddings, f, pickle.HIGHEST_PROTOCOL)

# word
filename = SAVE_TO + '/en_it_rand_500K_U_dec19.pkl'
with open(filename, 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(model_1.word_embeddings, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Evaluation

# %%
model_1.evaluate(source_lang = LANG[0], 
                 target_lang = LANG[1], 
                 gtt = GTT_DF, 
                 sample = EVAL_IDS,
                 top_k = 5,
                 verbose = True)
# Out:
# ... Model Initialized
# sim shape (8516, 20003)
# vocab size 20003
# word it_migliora
# half of vocab 10003
# word it_migliore
# half of vocab 10004
# word it_ritmica
# half of vocab 10005
# word it_platone
# half of vocab 10006
# word it_lentamente
# half of vocab 10007
# word it_promettente
# half of vocab 10008
# word it_consolidare
# half of vocab 10009
# word it_precisione
# half of vocab 10010
# word it_foto
# half of vocab 10011
# word it_queen
# half of vocab 10012
# word it_sonata
# half of vocab 10013
# word it_ginevra
# half of vocab 10014
# word it_sino
# half of vocab 10015
# word it_apre
# half of vocab 10016
# word it_spartiacque
# half of vocab 10017
# word it_consumo
# half of vocab 10018
# word it_vegetazione
# half of vocab 10019
# word it_limitare
# half of vocab 10020
# word it_cattura
# half of vocab 10021
# word it_sorprendente
# half of vocab 10022
# word it_cuori
# half of vocab 10023
# word it_improvviso
# half of vocab 10024
# word it_improvvisa
# half of vocab 10025
# word it_cuore
# half of vocab 10026
# word it_mostra
# half of vocab 10027
# word it_space
# half of vocab 10028
# word it_morente
# half of vocab 10029
# word it_rilevato
# half of vocab 10030
# word it_ribelle
# half of vocab 10031
# word it_gelosia
# half of vocab 10032
# word it_fifa
# half of vocab 10033
# word it_niente
# half of vocab 10034
# word it_volume
# half of vocab 10035
# word it_qualifica
# half of vocab 10036
# word it_notato
# half of vocab 10037
# word it_spera
# half of vocab 10038
# word it_celtica
# half of vocab 10039
# word it_rissa
# half of vocab 10040
# word it_iniezione
# half of vocab 10041
# word it_molla
# half of vocab 10042
# word it_vinile
# half of vocab 10043
# word it_molle
# half of vocab 10044
# word it_gente
# half of vocab 10045
# word it_saraceni
# half of vocab 10046
# word it_abbreviato
# half of vocab 10047
# word it_terra
# half of vocab 10048
# word it_turismo
# half of vocab 10049
# word it_theta
# half of vocab 10050
# word it_terre
# half of vocab 10051
# word it_carestia
# half of vocab 10052
# word it_olive
# half of vocab 10053
# word it_apple
# half of vocab 10054
# word it_oliva
# half of vocab 10055
# word it_fregata
# half of vocab 10056
# word it_notata
# half of vocab 10057
# word it_siluro
# half of vocab 10058
# word it_tram
# half of vocab 10059
# word it_cugino
# half of vocab 10060
# word it_soldato
# half of vocab 10061
# word it_efficiente
# half of vocab 10062
# word it_soldati
# half of vocab 10063
# word it_vangelo
# half of vocab 10064
# word it_venezuela
# half of vocab 10065
# word it_ravenna
# half of vocab 10066
# word it_raggiunto
# half of vocab 10067
# word it_papiro
# half of vocab 10068
# word it_fretta
# half of vocab 10069
# word it_mente
# half of vocab 10070
# word it_vagamente
# half of vocab 10071
# word it_genesi
# half of vocab 10072
# word it_gaetano
# half of vocab 10073
# word it_diagramma
# half of vocab 10074
# word it_jack
# half of vocab 10075
# word it_pulizia
# half of vocab 10076
# word it_archeologia
# half of vocab 10077
# word it_ramo
# half of vocab 10078
# word it_sentimento
# half of vocab 10079
# word it_innovazione
# half of vocab 10080
# word it_affrontare
# half of vocab 10081
# word it_suzuki
# half of vocab 10082
# word it_ucraino
# half of vocab 10083
# word it_pin
# half of vocab 10084
# word it_port
# half of vocab 10085
# word it_ucraina
# half of vocab 10086
# word it_forte
# half of vocab 10087
# word it_aspettare
# half of vocab 10088
# word it_bosco
# half of vocab 10089
# word it_uganda
# half of vocab 10090
# word it_incrociatore
# half of vocab 10091
# word it_acque
# half of vocab 10092
# word it_disco
# half of vocab 10093
# word it_acqua
# half of vocab 10094
# word it_cannes
# half of vocab 10095
# word it_fascista
# half of vocab 10096
# word it_bonaparte
# half of vocab 10097
# word it_man
# half of vocab 10098
# word it_pericolosità
# half of vocab 10099
# word it_fidanzata
# half of vocab 10100
# word it_disarmo
# half of vocab 10101
# word it_fidanzato
# half of vocab 10102
# word it_figure
# half of vocab 10103
# word it_consegnato
# half of vocab 10104
# word it_cadavere
# half of vocab 10105
# word it_emma
# half of vocab 10106
# word it_ferro
# half of vocab 10107
# word it_uefa
# half of vocab 10108
# word it_ferri
# half of vocab 10109
# word it_insediamento
# half of vocab 10110
# word it_peli
# half of vocab 10111
# word it_proiettile
# half of vocab 10112
# word it_robin
# half of vocab 10113
# word it_programmato
# half of vocab 10114
# word it_cadere
# half of vocab 10115
# word it_contea
# half of vocab 10116
# word it_autunno
# half of vocab 10117
# word it_sardegna
# half of vocab 10118
# word it_verticale
# half of vocab 10119
# word it_ghetto
# half of vocab 10120
# word it_opera
# half of vocab 10121
# word it_concorrenza
# half of vocab 10122
# word it_adelaide
# half of vocab 10123
# word it_tessile
# half of vocab 10124
# word it_pieno
# half of vocab 10125
# word it_spezia
# half of vocab 10126
# word it_martello
# half of vocab 10127
# word it_dean
# half of vocab 10128
# word it_misurare
# half of vocab 10129
# word it_polvere
# half of vocab 10130
# word it_primitiva
# half of vocab 10131
# word it_youtube
# half of vocab 10132
# word it_primitive
# half of vocab 10133
# word it_piuttosto
# half of vocab 10134
# word it_tenuta
# half of vocab 10135
# word it_originario
# half of vocab 10136
# word it_sciolto
# half of vocab 10137
# word it_australia
# half of vocab 10138
# word it_identità
# half of vocab 10139
# word it_romanzo
# half of vocab 10140
# word it_misterioso
# half of vocab 10141
# word it_volare
# half of vocab 10142
# word it_legno
# half of vocab 10143
# word it_sessione
# half of vocab 10144
# word it_substrato
# half of vocab 10145
# word it_vocazione
# half of vocab 10146
# word it_keith
# half of vocab 10147
# word it_legna
# half of vocab 10148
# word it_consigli
# half of vocab 10149
# word it_bergamo
# half of vocab 10150
# word it_biologia
# half of vocab 10151
# word it_virtuale
# half of vocab 10152
# word it_debutto
# half of vocab 10153
# word it_manhattan
# half of vocab 10154
# word it_istituto
# half of vocab 10155
# word it_generano
# half of vocab 10156
# word it_sorgenti
# half of vocab 10157
# word it_derivata
# half of vocab 10158
# word it_modella
# half of vocab 10159
# word it_modello
# half of vocab 10160
# word it_seriamente
# half of vocab 10161
# word it_editto
# half of vocab 10162
# word it_modelli
# half of vocab 10163
# word it_discreta
# half of vocab 10164
# word it_discreto
# half of vocab 10165
# word it_acquistato
# half of vocab 10166
# word it_evidente
# half of vocab 10167
# word it_eccezionale
# half of vocab 10168
# word it_png
# half of vocab 10169
# word it_proporre
# half of vocab 10170
# word it_sting
# half of vocab 10171
# word it_cabaret
# half of vocab 10172
# word it_offensivo
# half of vocab 10173
# word it_reportage
# half of vocab 10174
# word it_funghi
# half of vocab 10175
# word it_offensiva
# half of vocab 10176
# word it_fiction
# half of vocab 10177
# word it_racconto
# half of vocab 10178
# word it_canone
# half of vocab 10179
# word it_partito
# half of vocab 10180
# word it_racconta
# half of vocab 10181
# word it_diciannove
# half of vocab 10182
# word it_cera
# half of vocab 10183
# word it_prete
# half of vocab 10184
# word it_esaminare
# half of vocab 10185
# word it_adamo
# half of vocab 10186
# word it_accordo
# half of vocab 10187
# word it_potassio
# half of vocab 10188
# word it_adams
# half of vocab 10189
# word it_fattura
# half of vocab 10190
# word it_neoclassico
# half of vocab 10191
# word it_pisa
# half of vocab 10192
# word it_finire
# half of vocab 10193
# word it_dirigenti
# half of vocab 10194
# word it_cittadella
# half of vocab 10195
# word it_pensa
# half of vocab 10196
# word it_cura
# half of vocab 10197
# word it_vigore
# half of vocab 10198
# word it_franklin
# half of vocab 10199
# word it_associazione
# half of vocab 10200
# word it_genesis
# half of vocab 10201
# word it_frutti
# half of vocab 10202
# word it_elaborato
# half of vocab 10203
# word it_associazioni
# half of vocab 10204
# word it_frutto
# half of vocab 10205
# word it_salita
# half of vocab 10206
# word it_ritrovo
# half of vocab 10207
# word it_silla
# half of vocab 10208
# word it_cattolica
# half of vocab 10209
# word it_wolf
# half of vocab 10210
# word it_segreteria
# half of vocab 10211
# word it_annunciato
# half of vocab 10212
# word it_serra
# half of vocab 10213
# word it_anfibi
# half of vocab 10214
# word it_capolinea
# half of vocab 10215
# word it_tyler
# half of vocab 10216
# word it_fischer
# half of vocab 10217
# word it_regio
# half of vocab 10218
# word it_esplosivo
# half of vocab 10219
# word it_lega
# half of vocab 10220
# word it_danubio
# half of vocab 10221
# word it_regia
# half of vocab 10222
# word it_spalle
# half of vocab 10223
# word it_don
# half of vocab 10224
# word it_calice
# half of vocab 10225
# word it_asti
# half of vocab 10226
# word it_atena
# half of vocab 10227
# word it_frasi
# half of vocab 10228
# word it_contratti
# half of vocab 10229
# word it_suicida
# half of vocab 10230
# word it_dos
# half of vocab 10231
# word it_triassico
# half of vocab 10232
# word it_savona
# half of vocab 10233
# word it_anale
# half of vocab 10234
# word it_cina
# half of vocab 10235
# word it_costi
# half of vocab 10236
# word it_guardare
# half of vocab 10237
# word it_master
# half of vocab 10238
# word it_osservatori
# half of vocab 10239
# word it_veneti
# half of vocab 10240
# word it_veneto
# half of vocab 10241
# word it_stabile
# half of vocab 10242
# word it_proprietà
# half of vocab 10243
# word it_lezione
# half of vocab 10244
# word it_opzione
# half of vocab 10245
# word it_journal
# half of vocab 10246
# word it_clan
# half of vocab 10247
# word it_dotazione
# half of vocab 10248
# word it_denti
# half of vocab 10249
# word it_clay
# half of vocab 10250
# word it_settimanale
# half of vocab 10251
# word it_video
# half of vocab 10252
# word it_lubiana
# half of vocab 10253
# word it_dente
# half of vocab 10254
# word it_justice
# half of vocab 10255
# word it_rettangolare
# half of vocab 10256
# word it_saccheggio
# half of vocab 10257
# word it_cattolicesimo
# half of vocab 10258
# word it_larve
# half of vocab 10259
# word it_crociata
# half of vocab 10260
# word it_endemico
# half of vocab 10261
# word it_televisione
# half of vocab 10262
# word it_supergigante
# half of vocab 10263
# word it_conoscenze
# half of vocab 10264
# word it_conoscenza
# half of vocab 10265
# word it_tratto
# half of vocab 10266
# word it_cilindrico
# half of vocab 10267
# word it_laureata
# half of vocab 10268
# word it_laureato
# half of vocab 10269
# word it_concordia
# half of vocab 10270
# word it_glaciale
# half of vocab 10271
# word it_stringa
# half of vocab 10272
# word it_recentemente
# half of vocab 10273
# word it_cerca
# half of vocab 10274
# word it_allenamento
# half of vocab 10275
# word it_maxwell
# half of vocab 10276
# word it_niger
# half of vocab 10277
# word it_molly
# half of vocab 10278
# word it_nomadi
# half of vocab 10279
# word it_propulsore
# half of vocab 10280
# word it_luca
# half of vocab 10281
# word it_luce
# half of vocab 10282
# word it_houten
# half of vocab 10283
# word it_luci
# half of vocab 10284
# word it_amichevole
# half of vocab 10285
# word it_controversia
# half of vocab 10286
# word it_heidelberg
# half of vocab 10287
# word it_ryu
# half of vocab 10288
# word it_aliena
# half of vocab 10289
# word it_sorriso
# half of vocab 10290
# word it_onde
# half of vocab 10291
# word it_profilo
# half of vocab 10292
# word it_profili
# half of vocab 10293
# word it_beatrice
# half of vocab 10294
# word it_norvegia
# half of vocab 10295
# word it_anniversario
# half of vocab 10296
# word it_diciassette
# half of vocab 10297
# word it_scarto
# half of vocab 10298
# word it_eugene
# half of vocab 10299
# word it_pil
# half of vocab 10300
# word it_auschwitz
# half of vocab 10301
# word it_membrane
# half of vocab 10302
# word it_bersaglio
# half of vocab 10303
# word it_settentrionale
# half of vocab 10304
# word it_disciplina
# half of vocab 10305
# word it_contenere
# half of vocab 10306
# word it_discipline
# half of vocab 10307
# word it_rifugio
# half of vocab 10308
# word it_arena
# half of vocab 10309
# word it_klaus
# half of vocab 10310
# word it_seguaci
# half of vocab 10311
# word it_proclama
# half of vocab 10312
# word it_provino
# half of vocab 10313
# word it_seguace
# half of vocab 10314
# word it_pubblicare
# half of vocab 10315
# word it_cugina
# half of vocab 10316
# word it_nave
# half of vocab 10317
# word it_suo
# half of vocab 10318
# word it_persino
# half of vocab 10319
# word it_irlandese
# half of vocab 10320
# word it_sub
# half of vocab 10321
# word it_denuncia
# half of vocab 10322
# word it_sue
# half of vocab 10323
# word it_telecamera
# half of vocab 10324
# word it_sur
# half of vocab 10325
# word it_massimiliano
# half of vocab 10326
# word it_stemma
# half of vocab 10327
# word it_fata
# half of vocab 10328
# word it_infiorescenza
# half of vocab 10329
# word it_radiazioni
# half of vocab 10330
# word it_piccardia
# half of vocab 10331
# word it_vincere
# half of vocab 10332
# word it_schiavitù
# half of vocab 10333
# word it_biologici
# half of vocab 10334
# word it_meglio
# half of vocab 10335
# word it_biologica
# half of vocab 10336
# word it_psi
# half of vocab 10337
# word it_aggiornamento
# half of vocab 10338
# word it_scena
# half of vocab 10339
# word it_siria
# half of vocab 10340
# word it_determinante
# half of vocab 10341
# word it_viola
# half of vocab 10342
# word it_agricoltura
# half of vocab 10343
# word it_amelia
# half of vocab 10344
# word it_plurale
# half of vocab 10345
# word it_passione
# half of vocab 10346
# word it_rispettivamente
# half of vocab 10347
# word it_granata
# half of vocab 10348
# word it_preesistente
# half of vocab 10349
# word it_human
# half of vocab 10350
# word it_spiegazione
# half of vocab 10351
# word it_pipistrello
# half of vocab 10352
# word it_pena
# half of vocab 10353
# word it_gravità
# half of vocab 10354
# word it_moda
# half of vocab 10355
# word it_piombino
# half of vocab 10356
# word it_fonetica
# half of vocab 10357
# word it_coinvolto
# half of vocab 10358
# word it_divertimento
# half of vocab 10359
# word it_api
# half of vocab 10360
# word it_scherma
# half of vocab 10361
# word it_schermo
# half of vocab 10362
# word it_maometto
# half of vocab 10363
# word it_bristol
# half of vocab 10364
# word it_colpevole
# half of vocab 10365
# word it_inventore
# half of vocab 10366
# word it_michelle
# half of vocab 10367
# word it_ashley
# half of vocab 10368
# word it_indipendentemente
# half of vocab 10369
# word it_strutture
# half of vocab 10370
# word it_struttura
# half of vocab 10371
# word it_pallavolo
# half of vocab 10372
# word it_croato
# half of vocab 10373
# word it_mons
# half of vocab 10374
# word it_dritto
# half of vocab 10375
# word it_piumaggio
# half of vocab 10376
# word it_poliziotto
# half of vocab 10377
# word it_contenente
# half of vocab 10378
# word it_canti
# half of vocab 10379
# word it_caterina
# half of vocab 10380
# word it_canto
# half of vocab 10381
# word it_misurata
# half of vocab 10382
# word it_ribalta
# half of vocab 10383
# word it_aquile
# half of vocab 10384
# word it_parziale
# half of vocab 10385
# word it_franco
# half of vocab 10386
# word it_touch
# half of vocab 10387
# word it_fortemente
# half of vocab 10388
# word it_salerno
# half of vocab 10389
# word it_amare
# half of vocab 10390
# word it_bibliotecario
# half of vocab 10391
# word it_beck
# half of vocab 10392
# word it_reno
# half of vocab 10393
# word it_willie
# half of vocab 10394
# word it_collaboratore
# half of vocab 10395
# word it_prossimità
# half of vocab 10396
# word it_cantone
# half of vocab 10397
# word it_bartolomeo
# half of vocab 10398
# word it_lord
# half of vocab 10399
# word it_sottofamiglia
# half of vocab 10400
# word it_pokémon
# half of vocab 10401
# word it_voivodato
# half of vocab 10402
# word it_mulini
# half of vocab 10403
# word it_specialità
# half of vocab 10404
# word it_licenza
# half of vocab 10405
# word it_sigillo
# half of vocab 10406
# word it_licenze
# half of vocab 10407
# word it_polacchi
# half of vocab 10408
# word it_accusato
# half of vocab 10409
# word it_vestiti
# half of vocab 10410
# word it_curioso
# half of vocab 10411
# word it_perdono
# half of vocab 10412
# word it_accusata
# half of vocab 10413
# word it_apparizione
# half of vocab 10414
# word it_dawn
# half of vocab 10415
# word it_ordini
# half of vocab 10416
# word it_afghanistan
# half of vocab 10417
# word it_precedentemente
# half of vocab 10418
# word it_rocca
# half of vocab 10419
# word it_calvo
# half of vocab 10420
# word it_area
# half of vocab 10421
# word it_attribuire
# half of vocab 10422
# word it_evolutiva
# half of vocab 10423
# word it_sentito
# half of vocab 10424
# word it_nantes
# half of vocab 10425
# word it_difficilmente
# half of vocab 10426
# word it_germanico
# half of vocab 10427
# word it_proporzionale
# half of vocab 10428
# word it_sardo
# half of vocab 10429
# word it_polari
# half of vocab 10430
# word it_diocesano
# half of vocab 10431
# word it_polare
# half of vocab 10432
# word it_omar
# half of vocab 10433
# word it_sarda
# half of vocab 10434
# word it_winchester
# half of vocab 10435
# word it_tribunali
# half of vocab 10436
# word it_zara
# half of vocab 10437
# word it_registrare
# half of vocab 10438
# word it_attendere
# half of vocab 10439
# word it_vantaggio
# half of vocab 10440
# word it_mercoledì
# half of vocab 10441
# word it_devoto
# half of vocab 10442
# word it_borbone
# half of vocab 10443
# word it_rotta
# half of vocab 10444
# word it_lombardia
# half of vocab 10445
# word it_oscura
# half of vocab 10446
# word it_santuario
# half of vocab 10447
# word it_topo
# half of vocab 10448
# word it_cocaina
# half of vocab 10449
# word it_oscuro
# half of vocab 10450
# word it_topi
# half of vocab 10451
# word it_ministro
# half of vocab 10452
# word it_aderire
# half of vocab 10453
# word it_dichiarazione
# half of vocab 10454
# word it_manoscritto
# half of vocab 10455
# word it_cristianesimo
# half of vocab 10456
# word it_inizi
# half of vocab 10457
# word it_predecessore
# half of vocab 10458
# word it_incontri
# half of vocab 10459
# word it_perfetta
# half of vocab 10460
# word it_riunito
# half of vocab 10461
# word it_incontra
# half of vocab 10462
# word it_precedenza
# half of vocab 10463
# word it_emerso
# half of vocab 10464
# word it_marginale
# half of vocab 10465
# word it_gola
# half of vocab 10466
# word it_circolo
# half of vocab 10467
# word it_riposo
# half of vocab 10468
# word it_sorella
# half of vocab 10469
# word it_sorelle
# half of vocab 10470
# word it_carica
# half of vocab 10471
# word it_lirico
# half of vocab 10472
# word it_conosciuto
# half of vocab 10473
# word it_elevato
# half of vocab 10474
# word it_flashback
# half of vocab 10475
# word it_ultimi
# half of vocab 10476
# word it_scorrere
# half of vocab 10477
# word it_parere
# half of vocab 10478
# word it_nazionale
# half of vocab 10479
# word it_confusione
# half of vocab 10480
# word it_battuta
# half of vocab 10481
# word it_temperamento
# half of vocab 10482
# word it_edizione
# half of vocab 10483
# word it_franchi
# half of vocab 10484
# word it_commercianti
# half of vocab 10485
# word it_wimbledon
# half of vocab 10486
# word it_massimi
# half of vocab 10487
# word it_massimo
# half of vocab 10488
# word it_definita
# half of vocab 10489
# word it_definiti
# half of vocab 10490
# word it_contemporaneamente
# half of vocab 10491
# word it_marche
# half of vocab 10492
# word it_adolfo
# half of vocab 10493
# word it_ministeriale
# half of vocab 10494
# word it_pescatore
# half of vocab 10495
# word it_omonimo
# half of vocab 10496
# word it_progressivamente
# half of vocab 10497
# word it_pescatori
# half of vocab 10498
# word it_romanticismo
# half of vocab 10499
# word it_bassa
# half of vocab 10500
# word it_basso
# half of vocab 10501
# word it_abitazioni
# half of vocab 10502
# word it_reclutamento
# half of vocab 10503
# word it_forma
# half of vocab 10504
# word it_forme
# half of vocab 10505
# word it_sahara
# half of vocab 10506
# word it_carrie
# half of vocab 10507
# word it_torta
# half of vocab 10508
# word it_rappresentato
# half of vocab 10509
# word it_angel
# half of vocab 10510
# word it_ranch
# half of vocab 10511
# word it_complemento
# half of vocab 10512
# word it_avignone
# half of vocab 10513
# word it_provò
# half of vocab 10514
# word it_stargate
# half of vocab 10515
# word it_organista
# half of vocab 10516
# word it_monza
# half of vocab 10517
# word it_foggia
# half of vocab 10518
# word it_ripartire
# half of vocab 10519
# word it_proprietaria
# half of vocab 10520
# word it_manifesta
# half of vocab 10521
# word it_catturare
# half of vocab 10522
# word it_inaspettatamente
# half of vocab 10523
# word it_pensione
# half of vocab 10524
# word it_plotone
# half of vocab 10525
# word it_manifesto
# half of vocab 10526
# word it_rischio
# half of vocab 10527
# word it_stampo
# half of vocab 10528
# word it_pordenone
# half of vocab 10529
# word it_superiorità
# half of vocab 10530
# word it_muore
# half of vocab 10531
# word it_stampa
# half of vocab 10532
# word it_touchdown
# half of vocab 10533
# word it_località
# half of vocab 10534
# word it_tentare
# half of vocab 10535
# word it_significato
# half of vocab 10536
# word it_cotone
# half of vocab 10537
# word it_punta
# half of vocab 10538
# word it_docente
# half of vocab 10539
# word it_inciso
# half of vocab 10540
# word it_magonza
# half of vocab 10541
# word it_estrarre
# half of vocab 10542
# word it_stagno
# half of vocab 10543
# word it_pila
# half of vocab 10544
# word it_miscela
# half of vocab 10545
# word it_avviso
# half of vocab 10546
# word it_votazione
# half of vocab 10547
# word it_promozione
# half of vocab 10548
# word it_genitori
# half of vocab 10549
# word it_somalia
# half of vocab 10550
# word it_direttorio
# half of vocab 10551
# word it_faenza
# half of vocab 10552
# word it_rivera
# half of vocab 10553
# word it_agnese
# half of vocab 10554
# word it_rientro
# half of vocab 10555
# word it_presto
# half of vocab 10556
# word it_stefan
# half of vocab 10557
# word it_caravaggio
# half of vocab 10558
# word it_pacchetto
# half of vocab 10559
# word it_pacchetti
# half of vocab 10560
# word it_schiavi
# half of vocab 10561
# word it_rende
# half of vocab 10562
# word it_pennsylvania
# half of vocab 10563
# word it_quartieri
# half of vocab 10564
# word it_complicato
# half of vocab 10565
# word it_cielo
# half of vocab 10566
# word it_impressionante
# half of vocab 10567
# word it_generico
# half of vocab 10568
# word it_rifugiati
# half of vocab 10569
# word it_costruzioni
# half of vocab 10570
# word it_muratura
# half of vocab 10571
# word it_nato
# half of vocab 10572
# word it_dover
# half of vocab 10573
# word it_nate
# half of vocab 10574
# word it_acquisito
# half of vocab 10575
# word it_quarta
# half of vocab 10576
# word it_gusto
# half of vocab 10577
# word it_esplorazione
# half of vocab 10578
# word it_attorno
# half of vocab 10579
# word it_generica
# half of vocab 10580
# word it_editor
# half of vocab 10581
# word it_pala
# half of vocab 10582
# word it_retro
# half of vocab 10583
# word it_pale
# half of vocab 10584
# word it_cavalieri
# half of vocab 10585
# word it_urbano
# half of vocab 10586
# word it_parassiti
# half of vocab 10587
# word it_cavaliere
# half of vocab 10588
# word it_cessione
# half of vocab 10589
# word it_chang
# half of vocab 10590
# word it_slesia
# half of vocab 10591
# word it_totale
# half of vocab 10592
# word it_benevento
# half of vocab 10593
# word it_dialetti
# half of vocab 10594
# word it_contaminazione
# half of vocab 10595
# word it_fianchi
# half of vocab 10596
# word it_scuderie
# half of vocab 10597
# word it_esito
# half of vocab 10598
# word it_festeggiato
# half of vocab 10599
# word it_slogan
# half of vocab 10600
# word it_firmare
# half of vocab 10601
# word it_proibito
# half of vocab 10602
# word it_accuratamente
# half of vocab 10603
# word it_provenienza
# half of vocab 10604
# word it_assunzione
# half of vocab 10605
# word it_positivo
# half of vocab 10606
# word it_particolare
# half of vocab 10607
# word it_traguardo
# half of vocab 10608
# word it_mecenate
# half of vocab 10609
# word it_lunetta
# half of vocab 10610
# word it_ande
# half of vocab 10611
# word it_estremità
# half of vocab 10612
# word it_viaggiatori
# half of vocab 10613
# word it_marinai
# half of vocab 10614
# word it_civile
# half of vocab 10615
# word it_mole
# half of vocab 10616
# word it_molo
# half of vocab 10617
# word it_fugge
# half of vocab 10618
# word it_umana
# half of vocab 10619
# word it_mach
# half of vocab 10620
# word it_internamente
# half of vocab 10621
# word it_umani
# half of vocab 10622
# word it_invisibile
# half of vocab 10623
# word it_umano
# half of vocab 10624
# word it_tradurre
# half of vocab 10625
# word it_van
# half of vocab 10626
# word it_inno
# half of vocab 10627
# word it_genetico
# half of vocab 10628
# word it_brandeburgo
# half of vocab 10629
# word it_deep
# half of vocab 10630
# word it_slave
# half of vocab 10631
# word it_slavi
# half of vocab 10632
# word it_slavo
# half of vocab 10633
# word it_doria
# half of vocab 10634
# word it_installare
# half of vocab 10635
# word it_duello
# half of vocab 10636
# word it_discriminazione
# half of vocab 10637
# word it_portland
# half of vocab 10638
# word it_beat
# half of vocab 10639
# word it_aperture
# half of vocab 10640
# word it_plastiche
# half of vocab 10641
# word it_orgoglio
# half of vocab 10642
# word it_accidentalmente
# half of vocab 10643
# word it_dvd
# half of vocab 10644
# word it_stark
# half of vocab 10645
# word it_florida
# half of vocab 10646
# word it_mira
# half of vocab 10647
# word it_settanta
# half of vocab 10648
# word it_browser
# half of vocab 10649
# word it_batte
# half of vocab 10650
# word it_brevetto
# half of vocab 10651
# word it_spettacolo
# half of vocab 10652
# word it_dario
# half of vocab 10653
# word it_brevetti
# half of vocab 10654
# word it_assassino
# half of vocab 10655
# word it_cambiare
# half of vocab 10656
# word it_aggregazione
# half of vocab 10657
# word it_zappa
# half of vocab 10658
# word it_selezione
# half of vocab 10659
# word it_bronzo
# half of vocab 10660
# word it_polizia
# half of vocab 10661
# word it_emergere
# half of vocab 10662
# word it_garcia
# half of vocab 10663
# word it_consacrata
# half of vocab 10664
# word it_consacrato
# half of vocab 10665
# word it_destinazione
# half of vocab 10666
# word it_golfo
# half of vocab 10667
# word it_alberi
# half of vocab 10668
# word it_nascondere
# half of vocab 10669
# word it_comunicazione
# half of vocab 10670
# word it_romeo
# half of vocab 10671
# word it_nove
# half of vocab 10672
# word it_illustre
# half of vocab 10673
# word it_febbre
# half of vocab 10674
# word it_argo
# half of vocab 10675
# word it_hope
# half of vocab 10676
# word it_consolato
# half of vocab 10677
# word it_etnico
# half of vocab 10678
# word it_sentire
# half of vocab 10679
# word it_antifascista
# half of vocab 10680
# word it_notizie
# half of vocab 10681
# word it_maschi
# half of vocab 10682
# word it_rimanenti
# half of vocab 10683
# word it_teatro
# half of vocab 10684
# word it_messico
# half of vocab 10685
# word it_douglas
# half of vocab 10686
# word it_rimanente
# half of vocab 10687
# word it_caserma
# half of vocab 10688
# word it_esistenti
# half of vocab 10689
# word it_decisiva
# half of vocab 10690
# word it_albert
# half of vocab 10691
# word it_ungheresi
# half of vocab 10692
# word it_elfi
# half of vocab 10693
# word it_morso
# half of vocab 10694
# word it_ungherese
# half of vocab 10695
# word it_bicchiere
# half of vocab 10696
# word it_visuale
# half of vocab 10697
# word it_scritto
# half of vocab 10698
# word it_verona
# half of vocab 10699
# word it_piave
# half of vocab 10700
# word it_motocicletta
# half of vocab 10701
# word it_predatori
# half of vocab 10702
# word it_blues
# half of vocab 10703
# word it_permanenza
# half of vocab 10704
# word it_jordan
# half of vocab 10705
# word it_radici
# half of vocab 10706
# word it_impegnato
# half of vocab 10707
# word it_poesia
# half of vocab 10708
# word it_retrocessione
# half of vocab 10709
# word it_poesie
# half of vocab 10710
# word it_classica
# half of vocab 10711
# word it_bella
# half of vocab 10712
# word it_frost
# half of vocab 10713
# word it_remake
# half of vocab 10714
# word it_pertanto
# half of vocab 10715
# word it_tessuto
# half of vocab 10716
# word it_brasile
# half of vocab 10717
# word it_inclinazione
# half of vocab 10718
# word it_pubblicazione
# half of vocab 10719
# word it_caffè
# half of vocab 10720
# word it_reggimento
# half of vocab 10721
# word it_protetta
# half of vocab 10722
# word it_fortunata
# half of vocab 10723
# word it_mausoleo
# half of vocab 10724
# word it_esaurito
# half of vocab 10725
# word it_disposizioni
# half of vocab 10726
# word it_disposizione
# half of vocab 10727
# word it_suite
# half of vocab 10728
# word it_nudo
# half of vocab 10729
# word it_discussione
# half of vocab 10730
# word it_cracovia
# half of vocab 10731
# word it_avanguardia
# half of vocab 10732
# word it_ortodossa
# half of vocab 10733
# word it_nuda
# half of vocab 10734
# word it_jet
# half of vocab 10735
# word it_bbc
# half of vocab 10736
# word it_monastero
# half of vocab 10737
# word it_camilla
# half of vocab 10738
# word it_bull
# half of vocab 10739
# word it_jazz
# half of vocab 10740
# word it_adesione
# half of vocab 10741
# word it_riscaldamento
# half of vocab 10742
# word it_brasiliana
# half of vocab 10743
# word it_brasiliano
# half of vocab 10744
# word it_brasiliani
# half of vocab 10745
# word it_bibliografia
# half of vocab 10746
# word it_corridoio
# half of vocab 10747
# word it_lunare
# half of vocab 10748
# word it_identico
# half of vocab 10749
# word it_piramide
# half of vocab 10750
# word it_identica
# half of vocab 10751
# word it_foreste
# half of vocab 10752
# word it_foresta
# half of vocab 10753
# word it_diario
# half of vocab 10754
# word it_varianti
# half of vocab 10755
# word it_previsto
# half of vocab 10756
# word it_database
# half of vocab 10757
# word it_ford
# half of vocab 10758
# word it_freccia
# half of vocab 10759
# word it_fede
# half of vocab 10760
# word it_monte
# half of vocab 10761
# word it_monti
# half of vocab 10762
# word it_truffa
# half of vocab 10763
# word it_singapore
# half of vocab 10764
# word it_invece
# half of vocab 10765
# word it_polveri
# half of vocab 10766
# word it_corea
# half of vocab 10767
# word it_nullo
# half of vocab 10768
# word it_presbiterio
# half of vocab 10769
# word it_jimmy
# half of vocab 10770
# word it_nulla
# half of vocab 10771
# word it_dead
# half of vocab 10772
# word it_debolezza
# half of vocab 10773
# word it_rilevare
# half of vocab 10774
# word it_presenza
# half of vocab 10775
# word it_bus
# half of vocab 10776
# word it_purtroppo
# half of vocab 10777
# word it_bug
# half of vocab 10778
# word it_introduzione
# half of vocab 10779
# word it_sostegno
# half of vocab 10780
# word it_metz
# half of vocab 10781
# word it_occhi
# half of vocab 10782
# word it_rinascimento
# half of vocab 10783
# word it_forzato
# half of vocab 10784
# word it_sciolta
# half of vocab 10785
# word it_lang
# half of vocab 10786
# word it_magnesio
# half of vocab 10787
# word it_americhe
# half of vocab 10788
# word it_meta
# half of vocab 10789
# word it_lane
# half of vocab 10790
# word it_compilation
# half of vocab 10791
# word it_fanteria
# half of vocab 10792
# word it_cristallo
# half of vocab 10793
# word it_occidente
# half of vocab 10794
# word it_caverne
# half of vocab 10795
# word it_gary
# half of vocab 10796
# word it_pino
# half of vocab 10797
# word it_primitivi
# half of vocab 10798
# word it_facilitare
# half of vocab 10799
# word it_remoto
# half of vocab 10800
# word it_run
# half of vocab 10801
# word it_comprendere
# half of vocab 10802
# word it_rue
# half of vocab 10803
# word it_caverna
# half of vocab 10804
# word it_fred
# half of vocab 10805
# word it_free
# half of vocab 10806
# word it_piazzale
# half of vocab 10807
# word it_cori
# half of vocab 10808
# word it_guerriglia
# half of vocab 10809
# word it_tracia
# half of vocab 10810
# word it_immenso
# half of vocab 10811
# word it_primitivo
# half of vocab 10812
# word it_mesopotamia
# half of vocab 10813
# word it_parità
# half of vocab 10814
# word it_muto
# half of vocab 10815
# word it_patente
# half of vocab 10816
# word it_muta
# half of vocab 10817
# word it_pugno
# half of vocab 10818
# word it_quarto
# half of vocab 10819
# word it_armata
# half of vocab 10820
# word it_chiusi
# half of vocab 10821
# word it_scuro
# half of vocab 10822
# word it_chiuso
# half of vocab 10823
# word it_chiusa
# half of vocab 10824
# word it_chiuse
# half of vocab 10825
# word it_affiancato
# half of vocab 10826
# word it_scure
# half of vocab 10827
# word it_grafia
# half of vocab 10828
# word it_sollevamento
# half of vocab 10829
# word it_rovigo
# half of vocab 10830
# word it_spore
# half of vocab 10831
# word it_preferito
# half of vocab 10832
# word it_salvador
# half of vocab 10833
# word it_sport
# half of vocab 10834
# word it_genovese
# half of vocab 10835
# word it_uva
# half of vocab 10836
# word it_sostenitore
# half of vocab 10837
# word it_karen
# half of vocab 10838
# word it_pane
# half of vocab 10839
# word it_agenzia
# half of vocab 10840
# word it_ciurma
# half of vocab 10841
# word it_linguaggio
# half of vocab 10842
# word it_ricercato
# half of vocab 10843
# word it_alloggio
# half of vocab 10844
# word it_cimitero
# half of vocab 10845
# word it_potenza
# half of vocab 10846
# word it_belga
# half of vocab 10847
# word it_aprilia
# half of vocab 10848
# word it_task
# half of vocab 10849
# word it_alpini
# half of vocab 10850
# word it_alpino
# half of vocab 10851
# word it_alpina
# half of vocab 10852
# word it_entità
# half of vocab 10853
# word it_alpine
# half of vocab 10854
# word it_conclave
# half of vocab 10855
# word it_ripetutamente
# half of vocab 10856
# word it_anhalt
# half of vocab 10857
# word it_medicinali
# half of vocab 10858
# word it_reggenza
# half of vocab 10859
# word it_estetico
# half of vocab 10860
# word it_estetica
# half of vocab 10861
# word it_operaio
# half of vocab 10862
# word it_sotto
# half of vocab 10863
# word it_lavorare
# half of vocab 10864
# word it_provare
# half of vocab 10865
# word it_aurora
# half of vocab 10866
# word it_robot
# half of vocab 10867
# word it_firmato
# half of vocab 10868
# word it_quintetto
# half of vocab 10869
# word it_romantico
# half of vocab 10870
# word it_roccia
# half of vocab 10871
# word it_atalanta
# half of vocab 10872
# word it_abilità
# half of vocab 10873
# word it_roccaforte
# half of vocab 10874
# word it_pozzo
# half of vocab 10875
# word it_americana
# half of vocab 10876
# word it_interregionale
# half of vocab 10877
# word it_concistoro
# half of vocab 10878
# word it_americano
# half of vocab 10879
# word it_dimostrazione
# half of vocab 10880
# word it_telaio
# half of vocab 10881
# word it_toro
# half of vocab 10882
# word it_consulente
# half of vocab 10883
# word it_bagni
# half of vocab 10884
# word it_via
# half of vocab 10885
# word it_bagno
# half of vocab 10886
# word it_vic
# half of vocab 10887
# word it_tori
# half of vocab 10888
# word it_germano
# half of vocab 10889
# word it_libertà
# half of vocab 10890
# word it_piede
# half of vocab 10891
# word it_vincente
# half of vocab 10892
# word it_goal
# half of vocab 10893
# word it_viceré
# half of vocab 10894
# word it_potenziale
# half of vocab 10895
# word it_imprigionato
# half of vocab 10896
# word it_weekend
# half of vocab 10897
# word it_albergo
# half of vocab 10898
# word it_piquet
# half of vocab 10899
# word it_sopravvissuto
# half of vocab 10900
# word it_assumendo
# half of vocab 10901
# word it_annualmente
# half of vocab 10902
# word it_podestà
# half of vocab 10903
# word it_bielorussia
# half of vocab 10904
# word it_stile
# half of vocab 10905
# word it_venduta
# half of vocab 10906
# word it_perfino
# half of vocab 10907
# word it_magno
# half of vocab 10908
# word it_alberto
# half of vocab 10909
# word it_stirpe
# half of vocab 10910
# word it_one
# half of vocab 10911
# word it_vetro
# half of vocab 10912
# word it_onu
# half of vocab 10913
# word it_geologia
# half of vocab 10914
# word it_improvvisamente
# half of vocab 10915
# word it_rappresaglia
# half of vocab 10916
# word it_quinta
# half of vocab 10917
# word it_stato
# half of vocab 10918
# word it_manifestare
# half of vocab 10919
# word it_mite
# half of vocab 10920
# word it_mito
# half of vocab 10921
# word it_amante
# half of vocab 10922
# word it_hobbit
# half of vocab 10923
# word it_tragedia
# half of vocab 10924
# word it_vestibolo
# half of vocab 10925
# word it_vecchi
# half of vocab 10926
# word it_minerali
# half of vocab 10927
# word it_grosso
# half of vocab 10928
# word it_hamilton
# half of vocab 10929
# word it_adattamento
# half of vocab 10930
# word it_sita
# half of vocab 10931
# word it_camillo
# half of vocab 10932
# word it_sith
# half of vocab 10933
# word it_percorso
# half of vocab 10934
# word it_dominare
# half of vocab 10935
# word it_compleanno
# half of vocab 10936
# word it_perugia
# half of vocab 10937
# word it_ponte
# half of vocab 10938
# word it_pseudo
# half of vocab 10939
# word it_commercio
# half of vocab 10940
# word it_salvatore
# half of vocab 10941
# word it_ponto
# half of vocab 10942
# word it_costruisce
# half of vocab 10943
# word it_ponti
# half of vocab 10944
# word it_certamente
# half of vocab 10945
# word it_pensiero
# half of vocab 10946
# word it_pensieri
# half of vocab 10947
# word it_lingua
# half of vocab 10948
# word it_heaven
# half of vocab 10949
# word it_teologia
# half of vocab 10950
# word it_liberi
# half of vocab 10951
# word it_cemento
# half of vocab 10952
# word it_libera
# half of vocab 10953
# word it_eletto
# half of vocab 10954
# word it_didattico
# half of vocab 10955
# word it_nonostante
# half of vocab 10956
# word it_didattica
# half of vocab 10957
# word it_trono
# half of vocab 10958
# word it_toto
# half of vocab 10959
# word it_finito
# half of vocab 10960
# word it_usa
# half of vocab 10961
# word it_dolore
# half of vocab 10962
# word it_certi
# half of vocab 10963
# word it_praticare
# half of vocab 10964
# word it_mercantile
# half of vocab 10965
# word it_pellegrino
# half of vocab 10966
# word it_pianeta
# half of vocab 10967
# word it_maserati
# half of vocab 10968
# word it_pianeti
# half of vocab 10969
# word it_salento
# half of vocab 10970
# word it_probabilmente
# half of vocab 10971
# word it_derivato
# half of vocab 10972
# word it_grassetto
# half of vocab 10973
# word it_terribile
# half of vocab 10974
# word it_timpano
# half of vocab 10975
# word it_senato
# half of vocab 10976
# word it_salvataggio
# half of vocab 10977
# word it_ammasso
# half of vocab 10978
# word it_bisanzio
# half of vocab 10979
# word it_articolata
# half of vocab 10980
# word it_cronologia
# half of vocab 10981
# word it_articolato
# half of vocab 10982
# word it_nubi
# half of vocab 10983
# word it_gemelli
# half of vocab 10984
# word it_gemello
# half of vocab 10985
# word it_polmonare
# half of vocab 10986
# word it_nube
# half of vocab 10987
# word it_gemelle
# half of vocab 10988
# word it_marchesa
# half of vocab 10989
# word it_straordinari
# half of vocab 10990
# word it_marchese
# half of vocab 10991
# word it_crossover
# half of vocab 10992
# word it_espansione
# half of vocab 10993
# word it_dio
# half of vocab 10994
# word it_din
# half of vocab 10995
# word it_die
# half of vocab 10996
# word it_attila
# half of vocab 10997
# word it_ebraismo
# half of vocab 10998
# word it_corteccia
# half of vocab 10999
# word it_posti
# half of vocab 11000
# word it_digitale
# half of vocab 11001
# word it_respirazione
# half of vocab 11002
# word it_poema
# half of vocab 11003
# word it_family
# half of vocab 11004
# word it_garibaldi
# half of vocab 11005
# word it_formato
# half of vocab 11006
# word it_giornalista
# half of vocab 11007
# word it_colombia
# half of vocab 11008
# word it_nordest
# half of vocab 11009
# word it_boca
# half of vocab 11010
# word it_movimento
# half of vocab 11011
# word it_quadrato
# half of vocab 11012
# word it_affetto
# half of vocab 11013
# word it_inversa
# half of vocab 11014
# word it_sintetico
# half of vocab 11015
# word it_olandese
# half of vocab 11016
# word it_rango
# half of vocab 11017
# word it_spiegare
# half of vocab 11018
# word it_portale
# half of vocab 11019
# word it_folk
# half of vocab 11020
# word it_calcolare
# half of vocab 11021
# word it_delta
# half of vocab 11022
# word it_esponente
# half of vocab 11023
# word it_coniugi
# half of vocab 11024
# word it_nelson
# half of vocab 11025
# word it_collare
# half of vocab 11026
# word it_notazione
# half of vocab 11027
# word it_zecca
# half of vocab 11028
# word it_diffusione
# half of vocab 11029
# word it_palude
# half of vocab 11030
# word it_tradizionalmente
# half of vocab 11031
# word it_salomone
# half of vocab 11032
# word it_motori
# half of vocab 11033
# word it_paludi
# half of vocab 11034
# word it_affinità
# half of vocab 11035
# word it_sparta
# half of vocab 11036
# word it_tecnologia
# half of vocab 11037
# word it_decine
# half of vocab 11038
# word it_novità
# half of vocab 11039
# word it_alternativamente
# half of vocab 11040
# word it_dote
# half of vocab 11041
# word it_corazzata
# half of vocab 11042
# word it_traducibile
# half of vocab 11043
# word it_convertito
# half of vocab 11044
# word it_bandito
# half of vocab 11045
# word it_sodio
# half of vocab 11046
# word it_goethe
# half of vocab 11047
# word it_intel
# half of vocab 11048
# word it_molti
# half of vocab 11049
# word it_carey
# half of vocab 11050
# word it_consigliere
# half of vocab 11051
# word it_troppo
# half of vocab 11052
# word it_sessuale
# half of vocab 11053
# word it_tassonomia
# half of vocab 11054
# word it_documento
# half of vocab 11055
# word it_sistematica
# half of vocab 11056
# word it_elemento
# half of vocab 11057
# word it_elementi
# half of vocab 11058
# word it_documenti
# half of vocab 11059
# word it_decadenza
# half of vocab 11060
# word it_episodio
# half of vocab 11061
# word it_terzo
# half of vocab 11062
# word it_terza
# half of vocab 11063
# word it_desidera
# half of vocab 11064
# word it_immediata
# half of vocab 11065
# word it_amalia
# half of vocab 11066
# word it_orchi
# half of vocab 11067
# word it_nichel
# half of vocab 11068
# word it_lazio
# half of vocab 11069
# word it_comune
# half of vocab 11070
# word it_comuni
# half of vocab 11071
# word it_selezionato
# half of vocab 11072
# word it_anche
# half of vocab 11073
# word it_gravitazionale
# half of vocab 11074
# word it_cromosoma
# half of vocab 11075
# word it_paula
# half of vocab 11076
# word it_esprimere
# half of vocab 11077
# word it_disgrazia
# half of vocab 11078
# word it_chiostro
# half of vocab 11079
# word it_filippine
# half of vocab 11080
# word it_cerebrale
# half of vocab 11081
# word it_adiacenti
# half of vocab 11082
# word it_matura
# half of vocab 11083
# word it_fame
# half of vocab 11084
# word it_compiti
# half of vocab 11085
# word it_civiltà
# half of vocab 11086
# word it_adiacente
# half of vocab 11087
# word it_sette
# half of vocab 11088
# word it_pubblicato
# half of vocab 11089
# word it_pakistan
# half of vocab 11090
# word it_baia
# half of vocab 11091
# word it_solidarietà
# half of vocab 11092
# word it_altro
# half of vocab 11093
# word it_curve
# half of vocab 11094
# word it_riassunto
# half of vocab 11095
# word it_curva
# half of vocab 11096
# word it_bande
# half of vocab 11097
# word it_pur
# half of vocab 11098
# word it_primo
# half of vocab 11099
# word it_lunga
# half of vocab 11100
# word it_lungo
# half of vocab 11101
# word it_prima
# half of vocab 11102
# word it_pub
# half of vocab 11103
# word it_villa
# half of vocab 11104
# word it_dylan
# half of vocab 11105
# word it_formazione
# half of vocab 11106
# word it_spirit
# half of vocab 11107
# word it_vinci
# half of vocab 11108
# word it_grido
# half of vocab 11109
# word it_nell
# half of vocab 11110
# word it_trionfo
# half of vocab 11111
# word it_prosperità
# half of vocab 11112
# word it_riunione
# half of vocab 11113
# word it_ambasciatore
# half of vocab 11114
# word it_sollevato
# half of vocab 11115
# word it_conversione
# half of vocab 11116
# word it_tracciato
# half of vocab 11117
# word it_collega
# half of vocab 11118
# word it_college
# half of vocab 11119
# word it_crudele
# half of vocab 11120
# word it_brigata
# half of vocab 11121
# word it_acceso
# half of vocab 11122
# word it_marines
# half of vocab 11123
# word it_abile
# half of vocab 11124
# word it_banca
# half of vocab 11125
# word it_possibile
# half of vocab 11126
# word it_erodoto
# half of vocab 11127
# word it_volontà
# half of vocab 11128
# word it_cpu
# half of vocab 11129
# word it_iniziali
# half of vocab 11130
# word it_iniziale
# half of vocab 11131
# word it_tradizioni
# half of vocab 11132
# word it_luminosa
# half of vocab 11133
# word it_tradizione
# half of vocab 11134
# word it_luminoso
# half of vocab 11135
# word it_convenzionale
# half of vocab 11136
# word it_aggiornata
# half of vocab 11137
# word it_tranquillo
# half of vocab 11138
# word it_sciogliere
# half of vocab 11139
# word it_religiosa
# half of vocab 11140
# word it_religioso
# half of vocab 11141
# word it_kenya
# half of vocab 11142
# word it_prigionia
# half of vocab 11143
# word it_campus
# half of vocab 11144
# word it_evita
# half of vocab 11145
# word it_christine
# half of vocab 11146
# word it_mandato
# half of vocab 11147
# word it_faida
# half of vocab 11148
# word it_rivolta
# half of vocab 11149
# word it_provocato
# half of vocab 11150
# word it_soffrire
# half of vocab 11151
# word it_leggendario
# half of vocab 11152
# word it_altamente
# half of vocab 11153
# word it_manto
# half of vocab 11154
# word it_somme
# half of vocab 11155
# word it_programmazione
# half of vocab 11156
# word it_detenuto
# half of vocab 11157
# word it_diploma
# half of vocab 11158
# word it_passaggio
# half of vocab 11159
# word it_riferimento
# half of vocab 11160
# word it_pinna
# half of vocab 11161
# word it_altrimenti
# half of vocab 11162
# word it_pinne
# half of vocab 11163
# word it_biblioteche
# half of vocab 11164
# word it_cantiere
# half of vocab 11165
# word it_magnus
# half of vocab 11166
# word it_crede
# half of vocab 11167
# word it_conservare
# half of vocab 11168
# word it_ventimiglia
# half of vocab 11169
# word it_umanità
# half of vocab 11170
# word it_padiglione
# half of vocab 11171
# word it_aggiunta
# half of vocab 11172
# word it_luminosità
# half of vocab 11173
# word it_roman
# half of vocab 11174
# word it_economicamente
# half of vocab 11175
# word it_ironicamente
# half of vocab 11176
# word it_attuazione
# half of vocab 11177
# word it_parodia
# half of vocab 11178
# word it_sonda
# half of vocab 11179
# word it_tipicamente
# half of vocab 11180
# word it_miglioramento
# half of vocab 11181
# word it_mago
# half of vocab 11182
# word it_influente
# half of vocab 11183
# word it_partecipazione
# half of vocab 11184
# word it_completamente
# half of vocab 11185
# word it_maschera
# half of vocab 11186
# word it_condizione
# half of vocab 11187
# word it_miguel
# half of vocab 11188
# word it_cipro
# half of vocab 11189
# word it_penultimo
# half of vocab 11190
# word it_edgar
# half of vocab 11191
# word it_diabete
# half of vocab 11192
# word it_condizioni
# half of vocab 11193
# word it_curiosità
# half of vocab 11194
# word it_arco
# half of vocab 11195
# word it_distacco
# half of vocab 11196
# word it_tre
# half of vocab 11197
# word it_sola
# half of vocab 11198
# word it_sole
# half of vocab 11199
# word it_solo
# half of vocab 11200
# word it_velocemente
# half of vocab 11201
# word it_canada
# half of vocab 11202
# word it_ricognizione
# half of vocab 11203
# word it_elezione
# half of vocab 11204
# word it_artico
# half of vocab 11205
# word it_schieramento
# half of vocab 11206
# word it_sella
# half of vocab 11207
# word it_veicolo
# half of vocab 11208
# word it_carattere
# half of vocab 11209
# word it_ancona
# half of vocab 11210
# word it_spiritualità
# half of vocab 11211
# word it_cesare
# half of vocab 11212
# word it_redazione
# half of vocab 11213
# word it_giudizio
# half of vocab 11214
# word it_attratto
# half of vocab 11215
# word it_giovanile
# half of vocab 11216
# word it_doom
# half of vocab 11217
# word it_frutta
# half of vocab 11218
# word it_raffaello
# half of vocab 11219
# word it_aeronautica
# half of vocab 11220
# word it_macchia
# half of vocab 11221
# word it_apocalisse
# half of vocab 11222
# word it_cervo
# half of vocab 11223
# word it_conta
# half of vocab 11224
# word it_divino
# half of vocab 11225
# word it_mas
# half of vocab 11226
# word it_got
# half of vocab 11227
# word it_divina
# half of vocab 11228
# word it_conti
# half of vocab 11229
# word it_moderno
# half of vocab 11230
# word it_max
# half of vocab 11231
# word it_mac
# half of vocab 11232
# word it_mao
# half of vocab 11233
# word it_mal
# half of vocab 11234
# word it_sinagoga
# half of vocab 11235
# word it_gol
# half of vocab 11236
# word it_mai
# half of vocab 11237
# word it_veneziana
# half of vocab 11238
# word it_cattolico
# half of vocab 11239
# word it_infortuni
# half of vocab 11240
# word it_marino
# half of vocab 11241
# word it_navale
# half of vocab 11242
# word it_hockey
# half of vocab 11243
# word it_disperata
# half of vocab 11244
# word it_supervisione
# half of vocab 11245
# word it_croce
# half of vocab 11246
# word it_alloggi
# half of vocab 11247
# word it_sottomissione
# half of vocab 11248
# word it_loira
# half of vocab 11249
# word it_rally
# half of vocab 11250
# word it_specificatamente
# half of vocab 11251
# word it_antagonista
# half of vocab 11252
# word it_sacchi
# half of vocab 11253
# word it_polacca
# half of vocab 11254
# word it_polacco
# half of vocab 11255
# word it_vincolo
# half of vocab 11256
# word it_battere
# half of vocab 11257
# word it_puramente
# half of vocab 11258
# word it_patrocinio
# half of vocab 11259
# word it_molecolare
# half of vocab 11260
# word it_spalla
# half of vocab 11261
# word it_chitarrista
# half of vocab 11262
# word it_quarterback
# half of vocab 11263
# word it_successivamente
# half of vocab 11264
# word it_kiss
# half of vocab 11265
# word it_ricevute
# half of vocab 11266
# word it_ricevuta
# half of vocab 11267
# word it_telescopio
# half of vocab 11268
# word it_giglio
# half of vocab 11269
# word it_quercia
# half of vocab 11270
# word it_avviato
# half of vocab 11271
# word it_java
# half of vocab 11272
# word it_poker
# half of vocab 11273
# word it_fuoco
# half of vocab 11274
# word it_pirenei
# half of vocab 11275
# word it_rohan
# half of vocab 11276
# word it_luftwaffe
# half of vocab 11277
# word it_equatoriale
# half of vocab 11278
# word it_civico
# half of vocab 11279
# word it_protocollo
# half of vocab 11280
# word it_clero
# half of vocab 11281
# word it_mendoza
# half of vocab 11282
# word it_civica
# half of vocab 11283
# word it_territoriale
# half of vocab 11284
# word it_vestito
# half of vocab 11285
# word it_strutturale
# half of vocab 11286
# word it_trofeo
# half of vocab 11287
# word it_ordinare
# half of vocab 11288
# word it_investire
# half of vocab 11289
# word it_corriere
# half of vocab 11290
# word it_darwin
# half of vocab 11291
# word it_facilità
# half of vocab 11292
# word it_online
# half of vocab 11293
# word it_revolution
# half of vocab 11294
# word it_base
# half of vocab 11295
# word it_giove
# half of vocab 11296
# word it_aes
# half of vocab 11297
# word it_vende
# half of vocab 11298
# word it_renault
# half of vocab 11299
# word it_controllare
# half of vocab 11300
# word it_giacomo
# half of vocab 11301
# word it_città
# half of vocab 11302
# word it_godere
# half of vocab 11303
# word it_pontefice
# half of vocab 11304
# word it_scherzi
# half of vocab 11305
# word it_mondo
# half of vocab 11306
# word it_scherzo
# half of vocab 11307
# word it_definire
# half of vocab 11308
# word it_islanda
# half of vocab 11309
# word it_biennale
# half of vocab 11310
# word it_anita
# half of vocab 11311
# word it_parata
# half of vocab 11312
# word it_distante
# half of vocab 11313
# word it_diavolo
# half of vocab 11314
# word it_banchina
# half of vocab 11315
# word it_storica
# half of vocab 11316
# word it_vario
# half of vocab 11317
# word it_cercato
# half of vocab 11318
# ...
# word it_unesco
# half of vocab 18085
# word it_margine
# half of vocab 18086
# word it_mitologia
# half of vocab 18087
# word it_parete
# half of vocab 18088
# word it_pareti
# half of vocab 18089
# word it_fossato
# half of vocab 18090
# word it_canadesi
# half of vocab 18091
# word it_furto
# half of vocab 18092
# word it_buono
# half of vocab 18093
# word it_magistrato
# half of vocab 18094
# word it_molte
# half of vocab 18095
# word it_morale
# half of vocab 18096
# word it_peccati
# half of vocab 18097
# word it_slovacchia
# half of vocab 18098
# word it_buona
# half of vocab 18099
# word it_canadese
# half of vocab 18100
# word it_ontario
# half of vocab 18101
# word it_patria
# half of vocab 18102
# word it_viareggio
# half of vocab 18103
# word it_sindrome
# half of vocab 18104
# word it_charlotte
# half of vocab 18105
# word it_servo
# half of vocab 18106
# word it_calciatore
# half of vocab 18107
# word it_servi
# half of vocab 18108
# word it_arabia
# half of vocab 18109
# word it_federale
# half of vocab 18110
# word it_detenuti
# half of vocab 18111
# word it_leonardo
# half of vocab 18112
# word it_nicaragua
# half of vocab 18113
# word it_riso
# half of vocab 18114
# word it_ospiti
# half of vocab 18115
# word it_naturalistico
# half of vocab 18116
# word it_comportamento
# half of vocab 18117
# word it_mercato
# half of vocab 18118
# word it_mercati
# half of vocab 18119
# word it_comportamenti
# half of vocab 18120
# word it_corolla
# half of vocab 18121
# word it_scrittrice
# half of vocab 18122
# word it_coinvolgimento
# half of vocab 18123
# word it_celti
# half of vocab 18124
# word it_calcio
# half of vocab 18125
# word it_clientela
# half of vocab 18126
# word it_terminale
# half of vocab 18127
# word it_imporre
# half of vocab 18128
# word it_anelli
# half of vocab 18129
# word it_cher
# half of vocab 18130
# word it_cospirazione
# half of vocab 18131
# word it_sapienza
# half of vocab 18132
# word it_molecola
# half of vocab 18133
# word it_bocca
# half of vocab 18134
# word it_molecole
# half of vocab 18135
# word it_scalare
# half of vocab 18136
# word it_crescita
# half of vocab 18137
# word it_prospettiva
# half of vocab 18138
# word it_pippo
# half of vocab 18139
# word it_certo
# half of vocab 18140
# word it_documentata
# half of vocab 18141
# word it_khmer
# half of vocab 18142
# word it_artiglieria
# half of vocab 18143
# word it_stimata
# half of vocab 18144
# word it_terziario
# half of vocab 18145
# word it_loggia
# half of vocab 18146
# word it_deserto
# half of vocab 18147
# word it_visconte
# half of vocab 18148
# word it_utile
# half of vocab 18149
# word it_visconti
# half of vocab 18150
# word it_modesto
# half of vocab 18151
# word it_isolamento
# half of vocab 18152
# word it_esercizi
# half of vocab 18153
# word it_dance
# half of vocab 18154
# word it_gigantesca
# half of vocab 18155
# word it_salvare
# half of vocab 18156
# word it_adriatico
# half of vocab 18157
# word it_marittimo
# half of vocab 18158
# word it_accumulo
# half of vocab 18159
# word it_soffitto
# half of vocab 18160
# word it_ghiaccio
# half of vocab 18161
# word it_nevada
# half of vocab 18162
# word it_indipendente
# half of vocab 18163
# word it_segmento
# half of vocab 18164
# word it_invasione
# half of vocab 18165
# word it_fernando
# half of vocab 18166
# word it_client
# half of vocab 18167
# word it_recinto
# half of vocab 18168
# word it_connazionale
# half of vocab 18169
# word it_torre
# half of vocab 18170
# word it_atleta
# half of vocab 18171
# word it_torri
# half of vocab 18172
# word it_lasciare
# half of vocab 18173
# word it_assegnare
# half of vocab 18174
# word it_orizzontale
# half of vocab 18175
# word it_scavo
# half of vocab 18176
# word it_valtellina
# half of vocab 18177
# word it_manuale
# half of vocab 18178
# word it_fusione
# half of vocab 18179
# word it_abitato
# half of vocab 18180
# word it_pittsburgh
# half of vocab 18181
# word it_palme
# half of vocab 18182
# word it_ideale
# half of vocab 18183
# word it_risveglio
# half of vocab 18184
# word it_guillaume
# half of vocab 18185
# word it_registro
# half of vocab 18186
# word it_favorito
# half of vocab 18187
# word it_scapito
# half of vocab 18188
# word it_subito
# half of vocab 18189
# word it_vico
# half of vocab 18190
# word it_teste
# half of vocab 18191
# word it_postumo
# half of vocab 18192
# word it_degrado
# half of vocab 18193
# word it_vice
# half of vocab 18194
# word it_spirituale
# half of vocab 18195
# word it_servizio
# half of vocab 18196
# word it_cronologico
# half of vocab 18197
# word it_così
# half of vocab 18198
# word it_conserva
# half of vocab 18199
# word it_sicuramente
# half of vocab 18200
# word it_antenne
# half of vocab 18201
# word it_moltiplicazione
# half of vocab 18202
# word it_tuttavia
# half of vocab 18203
# word it_curtis
# half of vocab 18204
# word it_conquistare
# half of vocab 18205
# word it_millennio
# half of vocab 18206
# word it_agrigento
# half of vocab 18207
# word it_testi
# half of vocab 18208
# word it_disordine
# half of vocab 18209
# word it_evoluta
# half of vocab 18210
# word it_altopiano
# half of vocab 18211
# word it_evoluto
# half of vocab 18212
# word it_disordini
# half of vocab 18213
# word it_isola
# half of vocab 18214
# word it_milan
# half of vocab 18215
# word it_isole
# half of vocab 18216
# word it_caricato
# half of vocab 18217
# word it_accento
# half of vocab 18218
# word it_finzione
# half of vocab 18219
# word it_coma
# half of vocab 18220
# word it_insolito
# half of vocab 18221
# word it_pagamento
# half of vocab 18222
# word it_mantenere
# half of vocab 18223
# word it_zombie
# half of vocab 18224
# word it_citano
# half of vocab 18225
# word it_nucleare
# half of vocab 18226
# word it_testa
# half of vocab 18227
# word it_avvolto
# half of vocab 18228
# word it_cesena
# half of vocab 18229
# word it_poggio
# half of vocab 18230
# word it_uccello
# half of vocab 18231
# word it_amiche
# half of vocab 18232
# word it_uccelli
# half of vocab 18233
# word it_sacco
# half of vocab 18234
# word it_world
# half of vocab 18235
# word it_festeggiare
# half of vocab 18236
# word it_montare
# half of vocab 18237
# word it_qualcosa
# half of vocab 18238
# word it_indoor
# half of vocab 18239
# word it_professione
# half of vocab 18240
# word it_testo
# half of vocab 18241
# word it_gaspare
# half of vocab 18242
# word it_rinuncia
# half of vocab 18243
# word it_traghetto
# half of vocab 18244
# word it_simulazione
# half of vocab 18245
# word it_retto
# half of vocab 18246
# word it_back
# half of vocab 18247
# word it_adottare
# half of vocab 18248
# word it_musical
# half of vocab 18249
# word it_bach
# half of vocab 18250
# word it_istruttore
# half of vocab 18251
# word it_stampato
# half of vocab 18252
# word it_certificato
# half of vocab 18253
# word it_unità
# half of vocab 18254
# word it_lista
# half of vocab 18255
# word it_forze
# half of vocab 18256
# word it_alfredo
# half of vocab 18257
# word it_forza
# half of vocab 18258
# word it_pubblico
# half of vocab 18259
# word it_dinamo
# half of vocab 18260
# word it_fire
# half of vocab 18261
# word it_senegal
# half of vocab 18262
# word it_lastra
# half of vocab 18263
# word it_navetta
# half of vocab 18264
# word it_matteo
# half of vocab 18265
# word it_indossa
# half of vocab 18266
# word it_norme
# half of vocab 18267
# word it_intelligente
# half of vocab 18268
# word it_disegnatore
# half of vocab 18269
# word it_dolori
# half of vocab 18270
# word it_apprendimento
# half of vocab 18271
# word it_testamento
# half of vocab 18272
# word it_interpreti
# half of vocab 18273
# word it_vassallo
# half of vocab 18274
# word it_corrado
# half of vocab 18275
# word it_interprete
# half of vocab 18276
# word it_atp
# half of vocab 18277
# word it_appartamento
# half of vocab 18278
# word it_classe
# half of vocab 18279
# word it_binari
# half of vocab 18280
# word it_convegno
# half of vocab 18281
# word it_arricchito
# half of vocab 18282
# word it_inutile
# half of vocab 18283
# word it_diametro
# half of vocab 18284
# word it_vega
# half of vocab 18285
# word it_scenario
# half of vocab 18286
# word it_messaggero
# half of vocab 18287
# word it_dar
# half of vocab 18288
# word it_eccentricità
# half of vocab 18289
# word it_amministrazione
# half of vocab 18290
# word it_memorial
# half of vocab 18291
# word it_spaziale
# half of vocab 18292
# word it_quattordicesimo
# half of vocab 18293
# word it_memoria
# half of vocab 18294
# word it_camerino
# half of vocab 18295
# word it_orfeo
# half of vocab 18296
# word it_consistenza
# half of vocab 18297
# word it_angolare
# half of vocab 18298
# word it_cancellazione
# half of vocab 18299
# word it_sonno
# half of vocab 18300
# word it_cofano
# half of vocab 18301
# word it_regale
# half of vocab 18302
# word it_equipaggio
# half of vocab 18303
# word it_anello
# half of vocab 18304
# word it_regalo
# half of vocab 18305
# word it_obama
# half of vocab 18306
# word it_murray
# half of vocab 18307
# word it_sbarco
# half of vocab 18308
# word it_bolla
# half of vocab 18309
# word it_amsterdam
# half of vocab 18310
# word it_spettatore
# half of vocab 18311
# word it_sala
# half of vocab 18312
# word it_trasversale
# half of vocab 18313
# word it_nominale
# half of vocab 18314
# word it_politicamente
# half of vocab 18315
# word it_sali
# half of vocab 18316
# word it_installato
# half of vocab 18317
# word it_completamento
# half of vocab 18318
# word it_consigliato
# half of vocab 18319
# word it_teoria
# half of vocab 18320
# word it_teorie
# half of vocab 18321
# word it_california
# half of vocab 18322
# word it_oscar
# half of vocab 18323
# word it_agricola
# half of vocab 18324
# word it_attenzione
# half of vocab 18325
# word it_clinica
# half of vocab 18326
# word it_bovini
# half of vocab 18327
# word it_bratislava
# half of vocab 18328
# word it_clinico
# half of vocab 18329
# word it_palatinato
# half of vocab 18330
# word it_designato
# half of vocab 18331
# word it_baltico
# half of vocab 18332
# word it_avversaria
# half of vocab 18333
# word it_avversario
# half of vocab 18334
# word it_macerie
# half of vocab 18335
# word it_regime
# half of vocab 18336
# word it_leghe
# half of vocab 18337
# word it_trova
# half of vocab 18338
# word it_rand
# half of vocab 18339
# word it_munizioni
# half of vocab 18340
# word it_sinonimo
# half of vocab 18341
# word it_rettili
# half of vocab 18342
# word it_volata
# half of vocab 18343
# word it_paola
# half of vocab 18344
# word it_recitazione
# half of vocab 18345
# word it_carburante
# half of vocab 18346
# word it_paolo
# half of vocab 18347
# word it_attacca
# half of vocab 18348
# word it_nazista
# half of vocab 18349
# word it_longitudinale
# half of vocab 18350
# word it_figli
# half of vocab 18351
# word it_pompeo
# half of vocab 18352
# word it_tregua
# half of vocab 18353
# word it_attacco
# half of vocab 18354
# word it_graziano
# half of vocab 18355
# word it_quantità
# half of vocab 18356
# word it_interrotto
# half of vocab 18357
# word it_naturale
# half of vocab 18358
# word it_potenzialmente
# half of vocab 18359
# word it_costanti
# half of vocab 18360
# word it_leva
# half of vocab 18361
# word it_baschi
# half of vocab 18362
# word it_tana
# half of vocab 18363
# word it_sottomarino
# half of vocab 18364
# word it_nintendo
# half of vocab 18365
# word it_incredibilmente
# half of vocab 18366
# word it_costante
# half of vocab 18367
# word it_sheffield
# half of vocab 18368
# word it_felicità
# half of vocab 18369
# word it_dotato
# half of vocab 18370
# word it_terni
# half of vocab 18371
# word it_stilo
# half of vocab 18372
# word it_intervento
# half of vocab 18373
# word it_colombo
# half of vocab 18374
# word it_essere
# half of vocab 18375
# word it_dotata
# half of vocab 18376
# word it_confessione
# half of vocab 18377
# word it_scienziati
# half of vocab 18378
# word it_pompei
# half of vocab 18379
# word it_indagine
# half of vocab 18380
# word it_eccezione
# half of vocab 18381
# word it_combinata
# half of vocab 18382
# word it_rana
# half of vocab 18383
# word it_confessioni
# half of vocab 18384
# word it_marcato
# half of vocab 18385
# word it_comandante
# half of vocab 18386
# word it_imprenditori
# half of vocab 18387
# word it_cerimonia
# half of vocab 18388
# word it_imprenditore
# half of vocab 18389
# word it_consolare
# half of vocab 18390
# word it_vaccino
# half of vocab 18391
# word it_canna
# half of vocab 18392
# word it_rubare
# half of vocab 18393
# word it_catastrofe
# half of vocab 18394
# word it_ceppo
# half of vocab 18395
# word it_ispettore
# half of vocab 18396
# word it_trasferimento
# half of vocab 18397
# word it_midollo
# half of vocab 18398
# word it_voti
# half of vocab 18399
# word it_validità
# half of vocab 18400
# word it_allestimento
# half of vocab 18401
# word it_durezza
# half of vocab 18402
# word it_industriale
# half of vocab 18403
# word it_ceppi
# half of vocab 18404
# word it_mappe
# half of vocab 18405
# word it_protettore
# half of vocab 18406
# word it_lineare
# half of vocab 18407
# word it_fusti
# half of vocab 18408
# word it_qualificato
# half of vocab 18409
# word it_ghiacciaio
# half of vocab 18410
# word it_angolo
# half of vocab 18411
# word it_senior
# half of vocab 18412
# word it_filosofia
# half of vocab 18413
# word it_relativo
# half of vocab 18414
# word it_star
# half of vocab 18415
# word it_permanente
# half of vocab 18416
# word it_sicuro
# half of vocab 18417
# word it_familiare
# half of vocab 18418
# word it_tricolore
# half of vocab 18419
# word it_individuale
# half of vocab 18420
# word it_mandibola
# half of vocab 18421
# word it_separato
# half of vocab 18422
# word it_esami
# half of vocab 18423
# word it_assessore
# half of vocab 18424
# word it_separata
# half of vocab 18425
# word it_ella
# half of vocab 18426
# word it_robusta
# half of vocab 18427
# word it_sociologia
# half of vocab 18428
# word it_formale
# half of vocab 18429
# word it_ufo
# half of vocab 18430
# word it_incerta
# half of vocab 18431
# word it_tenere
# half of vocab 18432
# word it_tirolo
# half of vocab 18433
# word it_robusto
# half of vocab 18434
# word it_immacolata
# half of vocab 18435
# word it_barba
# half of vocab 18436
# word it_promise
# half of vocab 18437
# word it_francisco
# half of vocab 18438
# word it_dittatore
# half of vocab 18439
# word it_immaginare
# half of vocab 18440
# word it_furioso
# half of vocab 18441
# word it_spontanea
# half of vocab 18442
# word it_popolazione
# half of vocab 18443
# word it_gap
# half of vocab 18444
# word it_vicente
# half of vocab 18445
# word it_gas
# half of vocab 18446
# word it_marocco
# half of vocab 18447
# word it_gay
# half of vocab 18448
# word it_verso
# half of vocab 18449
# word it_aiuto
# half of vocab 18450
# word it_originale
# half of vocab 18451
# word it_deformazione
# half of vocab 18452
# word it_allievo
# half of vocab 18453
# word it_aiuta
# half of vocab 18454
# word it_coraggio
# half of vocab 18455
# word it_fuga
# half of vocab 18456
# word it_esploratori
# half of vocab 18457
# word it_campagna
# half of vocab 18458
# word it_medio
# half of vocab 18459
# word it_campagne
# half of vocab 18460
# word it_mosaico
# half of vocab 18461
# word it_aquileia
# half of vocab 18462
# word it_media
# half of vocab 18463
# word it_scopritore
# half of vocab 18464
# word it_cascina
# half of vocab 18465
# word it_binocolo
# half of vocab 18466
# word it_stima
# half of vocab 18467
# word it_elicottero
# half of vocab 18468
# word it_elicotteri
# half of vocab 18469
# word it_maresciallo
# half of vocab 18470
# word it_colla
# half of vocab 18471
# word it_lost
# half of vocab 18472
# word it_colle
# half of vocab 18473
# word it_colli
# half of vocab 18474
# word it_hardware
# half of vocab 18475
# word it_collo
# half of vocab 18476
# word it_marinaio
# half of vocab 18477
# word it_cantante
# half of vocab 18478
# word it_rinvio
# half of vocab 18479
# word it_ungheria
# half of vocab 18480
# word it_dai
# half of vocab 18481
# word it_coltello
# half of vocab 18482
# word it_concentrazione
# half of vocab 18483
# word it_dal
# half of vocab 18484
# word it_das
# half of vocab 18485
# word it_liquido
# half of vocab 18486
# word it_sveglia
# half of vocab 18487
# word it_tradimento
# half of vocab 18488
# word it_habitat
# half of vocab 18489
# word it_scarsità
# half of vocab 18490
# word it_estone
# half of vocab 18491
# word it_filosofico
# half of vocab 18492
# word it_albino
# half of vocab 18493
# word it_durazzo
# half of vocab 18494
# word it_purgatorio
# half of vocab 18495
# word it_scalata
# half of vocab 18496
# word it_alcol
# half of vocab 18497
# word it_approssimativamente
# half of vocab 18498
# word it_astronomia
# half of vocab 18499
# word it_bologna
# half of vocab 18500
# word it_geometria
# half of vocab 18501
# word it_missile
# half of vocab 18502
# word it_intorno
# half of vocab 18503
# word it_oklahoma
# half of vocab 18504
# word it_commonwealth
# half of vocab 18505
# word it_ezio
# half of vocab 18506
# word it_vercelli
# half of vocab 18507
# word it_stoccolma
# half of vocab 18508
# word it_polmone
# half of vocab 18509
# word it_documentari
# half of vocab 18510
# word it_romani
# half of vocab 18511
# word it_polmoni
# half of vocab 18512
# word it_liturgico
# half of vocab 18513
# word it_arancio
# half of vocab 18514
# word it_compiuta
# half of vocab 18515
# word it_chiunque
# half of vocab 18516
# word it_battle
# half of vocab 18517
# word it_soddisfacente
# half of vocab 18518
# Total successful translation rate: 0
# {'it_migliora': 0}
# {'it_migliora': 0}

# %%
evaluate(self, source_lang, target_lang, gtt, sample, verbose=True)

# %% [markdown]
# # Method 2: Most Common Target Translation

# %% [markdown]
# ### Initialize the model

# %%
from models import BiW2V_mle

# create model
model_2 = BiW2V_mle(bilingual_dict = translations,
                       vocab = vocab, H = EMBEDDING_SIZE)

# intialize TF graphs
model_2.BuildCoreGraph()
model_2.BuildTrainingGraph()
model_2.BuildValidationGraph()
# Out:
# ... TF graph created for BiW2V model.
# ... TF graph created for BiW2V training.
# ... TF graph created for BiW2V validation.

# %% [markdown]
# ### Training

# %%
# fresh data generator
DATA_GENERATOR = batch_generator(raw_data, vocab, BATCH_SIZE, WINDOW_SIZE, MAX_EPOCHS)

# %%
# train
start = time.time()
model_2.train(nBATCHES, DATA_GENERATOR, TEST_WORDS, learning_rate = ALPHA)
tot = (time.time() - start)
print('... {} batches trained in {} seconds'.format(nBATCHES, tot))
# Out:
# ... Model Initialized
# 	 <tf.Variable 'Embedding_Layer/ContextEmbeddings:0' shape=(20003, 200) dtype=float32_ref>
# 	 <tf.Variable 'Hidden_Layer/WordEmbeddings:0' shape=(20003, 200) dtype=float32_ref>
# 	 <tf.Variable 'Hidden_Layer/b:0' shape=(20003,) dtype=float32_ref>
# ... Starting Training
# ... STEP 0 : Average Loss : 0.00252045059204
#    [en_the] closest:  en_bern, en_mini, it_9, en_trout, en_gather, en_rival, en_homes, it_politica,
#    [en_last] closest:  it_led, en_idaho, it_funzioni, en_up, it_svevia, it_trascrizione, en_climbing, it_foto,
#    [it_si] closest:  en_6th, en_batting, en_reporter, en_shortened, it_alpini, it_tecnologie, en_addresses, en_credits,
#    [it_suo] closest:  en_overhead, en_rico, en_venice, it_provenza, it_raven, it_battezzato, it_fire, it_normativa,
# ... STEP 5000 : Average Loss : 4.71148335021
# ... STEP 10000 : Average Loss : 4.22817595466
#    [en_the] closest:  en_a, en_to, en_and, en_bern, en_mini, en_in, en_trout, it_politica,
#    [en_last] closest:  it_led, en_idaho, it_funzioni, en_up, it_trascrizione, it_svevia, en_climbing, it_foto,
#    [it_si] closest:  en_6th, en_reporter, it_tecnologie, en_batting, it_alpini, it_i, en_cleaning, en_cancelled,
#    [it_suo] closest:  en_overhead, en_venice, en_rico, it_fire, it_raven, it_provenza, it_niente, it_battezzato,
# ... STEP 15000 : Average Loss : 4.04906350614
# ... STEP 20000 : Average Loss : 4.0758832608
#    [en_the] closest:  en_a, en_to, en_and, en_in, en_bern, en_mini, en_electric, en_his,
#    [en_last] closest:  it_led, en_idaho, it_funzioni, en_up, it_svevia, it_trascrizione, it_foto, en_climbing,
#    [it_si] closest:  it_i, en_6th, en_reporter, it_tecnologie, it_alpini, en_batting, en_cancelled, en_cleaning,
#    [it_suo] closest:  en_overhead, en_venice, it_di, en_rico, it_fire, it_raven, it_provenza, it_niente,
# ... STEP 25000 : Average Loss : 3.99680838432
# ... STEP 30000 : Average Loss : 3.94877794099
#    [en_the] closest:  en_a, en_and, en_to, en_his, en_bern, en_in, en_an, en_its,
#    [en_last] closest:  en_idaho, it_led, it_funzioni, en_up, it_svevia, it_trascrizione, it_foto, en_climbing,
#    [it_si] closest:  it_i, en_6th, en_reporter, it_tecnologie, it_alpini, en_batting, it_in, en_cancelled,
#    [it_suo] closest:  it_di, en_overhead, en_venice, it_fire, it_raven, en_rico, it_stato, it_niente,
# ... STEP 35000 : Average Loss : 3.92520805442
# ... STEP 40000 : Average Loss : 3.90608162381
#    [en_the] closest:  en_a, en_his, en_and, en_its, en_an, en_in, en_bern, en_to,
#    [en_last] closest:  en_idaho, it_led, it_funzioni, en_up, it_trascrizione, it_svevia, it_foto, en_climbing,
#    [it_si] closest:  it_i, en_reporter, en_6th, it_tecnologie, it_alpini, it_in, en_batting, en_cancelled,
#    [it_suo] closest:  it_di, en_overhead, en_venice, it_dopo, it_fire, it_raven, en_rico, it_stato,
# ... STEP 45000 : Average Loss : 3.88112063468
# ... STEP 50000 : Average Loss : 3.82327789607
#    [en_the] closest:  en_a, en_his, en_its, en_an, en_this, en_and, en_bern, en_electric,
#    [en_last] closest:  en_idaho, it_led, it_funzioni, en_up, it_trascrizione, it_foto, it_svevia, en_climbing,
#    [it_si] closest:  it_i, en_reporter, en_6th, it_in, it_tecnologie, it_alpini, en_batting, it_le,
#    [it_suo] closest:  it_di, en_overhead, en_venice, it_dopo, it_raven, it_fire, it_stato, en_rico,
# ... Training Complete
# ... 50000 batches trained in 156.13361311 seconds

# %% [markdown]
# ### Save the Embeddings.

# %%
# context 
filename = SAVE_TO + '/en_it_mle_50K_V_dec19.pkl'
with open(filename, 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(model_2.context_embeddings, f, pickle.HIGHEST_PROTOCOL)

# word
filename = SAVE_TO + '/en_it_mle_50K_U_dec19.pkl'
with open(filename, 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(model_2.word_embeddings, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Method 3: Closest Translation

# %% [markdown]
# ### Initialize the model

# %%
from models import BiW2V_nn

# create model
model_3 = BiW2V_nn(bilingual_dict = translations,
                   vocab = vocab, H = EMBEDDING_SIZE)

# intialize TF graphs
model_3.BuildCoreGraph()
model_3.BuildTrainingGraph()
model_3.BuildValidationGraph()
# Out:
# ... TF graph created for BiW2V model.
# ... TF graph created for BiW2V training.
# ... TF graph created for BiW2V validation.

# %% [markdown]
# ### Training

# %%
# fresh data generator
DATA_GENERATOR = batch_generator(raw_data, vocab, BATCH_SIZE, WINDOW_SIZE, MAX_EPOCHS)

# %%
# train
nBATCHES = 5000 # Takes too long w/ nn so we'll only do 5K
start = time.time()
model_3.train(nBATCHES, DATA_GENERATOR, TEST_WORDS, learning_rate = ALPHA)
tot = (time.time() - start)
print('... {} batches trained in {} seconds'.format(nBATCHES, tot))
# Out:
# ... Model Initialized
# 	 <tf.Variable 'Embedding_Layer/ContextEmbeddings:0' shape=(20003, 200) dtype=float32_ref>
# 	 <tf.Variable 'Hidden_Layer/WordEmbeddings:0' shape=(20003, 200) dtype=float32_ref>
# 	 <tf.Variable 'Hidden_Layer/b:0' shape=(20003,) dtype=float32_ref>
# ... Starting Training
# ... STEP 0 : Average Loss : 0.02340858078
#    [en_the] closest:  en_nutrition, it_ma, en_prolonged, it_falco, it_vercelli, en_artists, en_beliefs, it_idraulico,
#    [en_last] closest:  en_earn, en_renowned, it_decadimento, it_boy, en_korea, en_basement, en_resulting, en_told,
#    [it_si] closest:  en_qualities, it_generato, it_scuole, en_employer, en_situation, en_chorus, en_to, en_inadequate,
#    [it_suo] closest:  en_sat, it_rimpiazzare, en_playing, it_triangolare, it_realmente, en_profile, it_tutta, it_stirpe,
# ... STEP 500 : Average Loss : 6.30888293695
# ... STEP 1000 : Average Loss : 5.52120716763
#    [en_the] closest:  en_nutrition, en_artists, it_falco, it_ma, en_beliefs, it_saturno, it_anime, it_siccità,
#    [en_last] closest:  en_earn, en_renowned, it_decadimento, it_boy, en_korea, en_basement, en_resulting, en_told,
#    [it_si] closest:  en_qualities, it_generato, it_scuole, en_to, en_employer, en_chorus, en_situation, en_inadequate,
#    [it_suo] closest:  en_sat, it_rimpiazzare, en_playing, it_triangolare, it_realmente, it_tutta, en_profile, en_spirits,
# ... STEP 1500 : Average Loss : 5.36810376883
# ... STEP 2000 : Average Loss : 5.16852718353
#    [en_the] closest:  en_nutrition, en_artists, it_falco, it_ma, en_beliefs, it_saturno, it_siccità, it_anime,
#    [en_last] closest:  en_earn, en_renowned, it_decadimento, it_boy, en_korea, en_basement, en_resulting, en_told,
#    [it_si] closest:  en_qualities, it_scuole, it_generato, en_to, en_employer, en_chorus, en_situation, en_inadequate,
#    [it_suo] closest:  en_sat, it_rimpiazzare, en_playing, it_triangolare, it_tutta, it_realmente, en_profile, en_spirits,
# ... STEP 2500 : Average Loss : 5.13391390038
# ... STEP 3000 : Average Loss : 5.07301244187
#    [en_the] closest:  en_nutrition, en_artists, it_falco, it_ma, it_saturno, it_siccità, en_beliefs, en_bengal,
#    [en_last] closest:  en_renowned, en_earn, it_decadimento, it_boy, en_korea, en_basement, en_resulting, en_told,
#    [it_si] closest:  en_qualities, en_to, it_scuole, it_generato, en_employer, en_chorus, en_situation, en_inadequate,
#    [it_suo] closest:  en_sat, it_rimpiazzare, en_playing, it_tutta, it_triangolare, it_realmente, en_profile, en_spirits,
# ... STEP 3500 : Average Loss : 5.01885948992
# ... STEP 4000 : Average Loss : 5.05571406984
#    [en_the] closest:  en_nutrition, en_a, en_artists, it_falco, it_ma, it_siccità, en_bengal, it_anime,
#    [en_last] closest:  en_earn, en_renowned, it_decadimento, it_boy, en_korea, en_basement, en_resulting, en_turin,
#    [it_si] closest:  en_qualities, en_to, it_scuole, en_employer, it_generato, en_chorus, en_situation, en_inadequate,
#    [it_suo] closest:  en_sat, it_rimpiazzare, en_playing, it_tutta, it_triangolare, it_realmente, en_profile, en_spirits,
# ... STEP 4500 : Average Loss : 4.97535962629
# ... STEP 5000 : Average Loss : 4.9615819416
#    [en_the] closest:  en_nutrition, en_a, it_falco, en_artists, it_ma, en_bengal, it_siccità, it_anime,
#    [en_last] closest:  en_renowned, en_earn, it_decadimento, it_boy, en_korea, en_basement, en_resulting, en_turin,
#    [it_si] closest:  en_qualities, en_to, it_scuole, en_employer, it_generato, en_chorus, en_preston, it_sceso,
#    [it_suo] closest:  en_sat, it_rimpiazzare, en_playing, it_tutta, it_realmente, it_triangolare, en_profile, en_spirits,
# ... Training Complete
# ... 5000 batches trained in 1766.22677398 seconds

# %% [markdown]
# ### Save the Embeddings.

# %%
# context 
filename = SAVE_TO + '/en_it_nn_5K_V_dec19.pkl'
with open(filename, 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(model_2.context_embeddings, f, pickle.HIGHEST_PROTOCOL)

# word
filename = SAVE_TO + '/en_it_nn_5K_U_dec19.pkl'
with open(filename, 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(model_2.word_embeddings, f, pickle.HIGHEST_PROTOCOL)
